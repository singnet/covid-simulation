# %%
import sys
sys.path.insert(0, '../..')
import copy
import numpy as np
from model.base import CovidModel, SimulationParameters, set_parameters, normal_ci
from utils import BasicStatistics, RemovePolicy, Propaganda, setup_city_layout, AddPolicyInfectedRate, confidence_interval, multiple_runs
from model.utils import SocialPolicy

# %%
listeners = [
["AddPolicyInfectedRateWindow", SocialPolicy.LOCKDOWN_ELEMENTARY_SCHOOL,0.00025 ,11],
["AddPolicyInfectedRateWindow", SocialPolicy.LOCKDOWN_MIDDLE_SCHOOL, 0.00025 ,11],
["AddPolicyInfectedRateWindow", SocialPolicy.LOCKDOWN_HIGH_SCHOOL, 0.00025 ,11],
["AddPolicyInfectedRateWindow", SocialPolicy.LOCKDOWN_RETAIL,0.00025 ,11],
["AddPolicyInfectedRateWindow", SocialPolicy.LOCKDOWN_FACTORY, 0.00025 ,11],
["AddPolicyInfectedRateWindow", SocialPolicy.LOCKDOWN_OFFICE, 0.00025 ,11],
["RemovePolicyInfectedRateWindow", SocialPolicy.LOCKDOWN_ELEMENTARY_SCHOOL, 0.00025 ,21],
["RemovePolicyInfectedRateWindow", SocialPolicy.LOCKDOWN_MIDDLE_SCHOOL, 0.00025 ,21],
["RemovePolicyInfectedRateWindow", SocialPolicy.LOCKDOWN_HIGH_SCHOOL,0.00025 ,21],
["RemovePolicyInfectedRateWindow", SocialPolicy.LOCKDOWN_RETAIL, 0.00025 ,21],
["RemovePolicyInfectedRateWindow", SocialPolicy.LOCKDOWN_FACTORY, 0.00025 ,21],
["RemovePolicyInfectedRateWindow", SocialPolicy.LOCKDOWN_OFFICE,0.00025 ,21]
]

# %%
common_parameters = SimulationParameters(
    mask_user_rate = 0.9, # 0.0,
    mask_efficacy = 0.6, #0.0,
    imune_rate = 0.01,
    initial_infection_rate = 0.01,
    hospitalization_capacity = 0.05,
    latency_period_shape = 3,
    latency_period_scale = 1, 
    incubation_period_shape = 6,
    incubation_period_scale = 1, 
    mild_period_duration_shape = 14,
    mild_period_duration_scale = 1,
    hospitalization_period_duration_shape = 12,
    hospitalization_period_duration_scale = 1,
    symptomatic_isolation_rate = 0.0,
    asymptomatic_contagion_probability = 0.1,
#    asymptomatic_contagion_probability = 0.05,
    risk_tolerance_mean = 0.7,
    risk_tolerance_stdev = 0.2,
    herding_behavior_mean = 0.7,
#    herding_behavior_mean = 0.1,
    herding_behavior_stdev = 0.2,
    allowed_restaurant_capacity = 0.25, #1.0, # valid values: {1.0, 0.50, 0.25}
    spreading_rate = normal_ci(2.41, 3.90, 20)
#    spreading_rate = normal_ci(0.5, 1.5, 20)
)

sc = 10

population_size = 1000
simulation_cycles = 360 # days
seed = 31415
np.random.seed(seed)

params = copy.deepcopy(common_parameters)

# %% [markdown]
# By changing the coverage of school and work districts over the home districts we can make the disease spread faster or slower as desired .
# def setup_grid_layout(model, population_size,
#         home_grid_height, home_grid_width,work_height,work_width, school_height, school_width):
#
#
# Makes a grid of homogeneous home districts, overlaid by school and work districts.
#
#
# home_grid_height is the number of home districts high the grid is, and
#
#
# home_grid_width is the nmber of home districts wide the grid is
#
#
# school height and work height are how many home districts high a school
#
#
# district and work are respectively, and the same for their length.
#
#
# each begins in grid 0,0 and cover the orignal home district grid.
#
#
# Persons assigned to the home districts are also assigned to the school
#
#
# and work districts that cover them. The parameters determine the amount
#
#
# of leakage across groups of people.  With parameters (10,10,1,1,1,1), you get 100
#
#
# completely separated districts with no leakage.  With parameters (6,6,2,2,3,3), illustrated below, you
#
#
# get a grid where every one is connected to everyone else, but there is a
#
#
# degree of separation.  For example, a person in home district (0,0) can be infected
#
#
# by a person in (5,5) but it would be bridged by three infections, slowing the
#
#
# virus down.  Larger sizes for work and school districts enable faster spread. Fastest
#
#
# spread occurs with parameters (1,1,1,1,1,1) or equivalently (10,10, 10,10,10,10)
#
#
# or any of the same number
#
#
# Since this is just a way to allocate human interactions, no label is needed and
#
#
# the grid need not be saved, for interactions to occur, although this informamtion
#
#
# may be useful for visualizations.

# %% [markdown]
# <img src="grids.jpg">

# %% [markdown]
#  Without locality, the defaults to multiple_run are :  home_grid_height = 1, home_grid_width = 1,work_height = 1, work_width =1, school_height=1, school_width=1.

# %%
import logging
def setLevel(level):
    logger1 = logging.getLogger()
    logger1.setLevel(level)
params.params['temperature'] = -0.99
params.params['num_communities'] = 12
seeds = [9675]
setLevel(logging.CRITICAL)
multiple_runs(params,population_size,simulation_cycles,seeds = seeds,fname = "duong10000-1", 
              do_print = True, 
              home_grid_height = 5, home_grid_width = 5, school_home_list = 
              [[(0,0),(0,1),(1,1),(2,1),(2,0),(1,0)],
               [(0,2),(0,3),(0,4),(1,3),(2,3),(2,2),(1,2)],
               [(1,4),(2,4),(3,4),(4,4)],
               [(3,3),(4,3),(4,2),(3,2),(3,1),(4,1),(4,0),(3,0)]],
              work_home_list = 
              [[(0,0),(0,1),(1,1),(2,1),(2,0),(1,0),
               (0,2),(0,3),(0,4),(1,3),(2,3),(2,2),(1,2),
               (1,4),(2,4),(3,4),(4,4),
               (3,3),(4,3),(4,2),(3,2),(3,1),(4,1),(4,0),(3,0)]],
              listeners = listeners)
# Out:
# Save these seeds if you want to rerun a scenario
# [9675]
# log initialized
# Average similarity between family members is -0.6556456973852574 at temperature -0.99
# Average similarity between family and home is -0.7222372345157421 at temperature -1
# Average similarity between students and their classroom is -0.712528318624892 at temperature -1
# Average similarity between workers is -0.5895800178052119 at temperature -1
# Average friend similarity for adults: 0.12753672674409644 for kids: 0.45169916636853136
# run with seed 9675:
# avg restaurant similarity 0.048520609855298054
# avg restaurant similarity 0.05573538288802778
# avg restaurant similarity -0.023361098987412877
# avg restaurant similarity -0.20797311606202193
# avg restaurant similarity -0.1559688217719016
# avg restaurant similarity -0.14785690094122653
# avg restaurant similarity -0.0707504074543142
# avg restaurant similarity -0.07699898143864997
# avg restaurant similarity -0.06949158035256901
# avg restaurant similarity -0.15557782369769477
# avg restaurant similarity -0.0724487703664877
# avg restaurant similarity -0.06830775214446662
# avg restaurant similarity -0.013673824505943807
# avg restaurant similarity -0.17617004941373524
# avg restaurant similarity -0.21004070460347066
# avg restaurant similarity -0.024159024192361257
# avg restaurant similarity -0.044578847228038225
# avg restaurant similarity -0.11187641289960702
# avg restaurant similarity -0.12175168516881511
# avg restaurant similarity -0.12950467045210726
# avg restaurant similarity -0.059049944320274196
# avg restaurant similarity -0.17495478493006472
# avg restaurant similarity -0.16619022086090277
# avg restaurant similarity -0.1264047612605331
# avg restaurant similarity -0.02870428366418939
# avg restaurant similarity -0.07267429824277029
# avg restaurant similarity -0.12766435487054154
# avg restaurant similarity -0.0331536185087102
# avg restaurant similarity -0.05568824098045079
# avg restaurant similarity 0.014776112797832641
# avg restaurant similarity -0.13759019306078657
# avg restaurant similarity -0.14780580543667746
# avg restaurant similarity 0.0888531588960351
# avg restaurant similarity -0.04791319878316659
# avg restaurant similarity -0.13115114927707675
# avg restaurant similarity -0.04111369958783037
# avg restaurant similarity 0.014321798471154957
# avg restaurant similarity -0.16564345223239557
# avg restaurant similarity -0.036350687935948915
# avg restaurant similarity 0.020477996843085405
# avg restaurant similarity 0.0486293134818522
# avg restaurant similarity 0.036345570623532275
# avg restaurant similarity -0.0017411245336061676
# avg restaurant similarity -0.029673947861553095
# avg restaurant similarity -0.051501620173662846
# avg restaurant similarity -0.03595036998165115
# avg restaurant similarity 0.07841655041163587
# avg restaurant similarity -0.008332846420392934
# avg restaurant similarity -0.012659142892961078
# avg restaurant similarity -0.23756875911966152
# avg restaurant similarity -0.177409002985481
# avg restaurant similarity -0.1319414048899814
# avg restaurant similarity -0.1449965727682446
# avg restaurant similarity -0.18424204481856157
# avg restaurant similarity -0.2239135962902219
# avg restaurant similarity -0.029127839792522193
# avg restaurant similarity -0.034818952067567153
# avg restaurant similarity -0.08205903422190812
# avg restaurant similarity -0.15387906700589213
# avg restaurant similarity -0.06437723715511333
# avg restaurant similarity -0.017123750087893155
# avg restaurant similarity -0.1024709966639686
# avg restaurant similarity -0.07430901011843428
# avg restaurant similarity -0.07563504151321142
# avg restaurant similarity -0.03917091163012521
# avg restaurant similarity 0.04188779318276312
# avg restaurant similarity -0.06300186828177713
# avg restaurant similarity 0.008590335385151603
# avg restaurant similarity -0.11563246834491481
# avg restaurant similarity -0.06684784930487721
# avg restaurant similarity -0.07845566285942564
# avg restaurant similarity -0.12879037257184522
# avg restaurant similarity 0.003618930641254239
# avg restaurant similarity 0.04453283879831107
# avg restaurant similarity -0.12448779942160171
# avg restaurant similarity -0.09537970993238132
# avg restaurant similarity -0.016763459796696717
# avg restaurant similarity -0.1038595097468031
# avg restaurant similarity -0.10169957797696662
# avg restaurant similarity -0.1261708057705957
# avg restaurant similarity 0.0029670365874538995
# avg restaurant similarity -0.03529856489242658
# avg restaurant similarity -0.1456571388072566
# avg restaurant similarity -0.06592147560567553
# avg restaurant similarity -0.12745220705771926
# avg restaurant similarity -0.09637862996235826
# avg restaurant similarity -0.06031229166503718
# avg restaurant similarity -0.14445158747896855
# avg restaurant similarity -0.23609632619177812
# avg restaurant similarity -0.14277586725116284
# avg restaurant similarity -0.18088376473393608
# avg restaurant similarity -0.15600179455026467
# avg restaurant similarity -0.08113338281855968
# avg restaurant similarity -0.1219090030278678
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# using average of time series:
# stats on susceptible:
# data: [0.4825527777777778]
# min:
# 0.4825527777777778
# max:
# 0.4825527777777778
# std:
# 0.0
# mean:
# 0.4825527777777778
# median:
# 0.4825527777777778
# 95% confidence interval for the mean:
# (nan,nan)
# using average of time series:
# stats on infected:
# data: [0.0388]
# min:
# 0.0388
# max:
# 0.0388
# std:
# 0.0
# mean:
# 0.0388
# median:
# 0.0388
# 95% confidence interval for the mean:
# (nan,nan)
# using average of time series:
# stats on recovered:
# data: [0.45133055555555557]
# min:
# 0.45133055555555557
# max:
# 0.45133055555555557
# std:
# 0.0
# mean:
# 0.45133055555555557
# median:
# 0.45133055555555557
# 95% confidence interval for the mean:
# (nan,nan)
# using average of time series:
# stats on hospitalization:
# data: [0.0063999999999999994]
# min:
# 0.0063999999999999994
# max:
# 0.0063999999999999994
# std:
# 0.0
# mean:
# 0.0063999999999999994
# median:
# 0.0063999999999999994
# 95% confidence interval for the mean:
# (nan,nan)
# using average of time series:
# stats on icu:
# data: [0.0015694444444444447]
# min:
# 0.0015694444444444447
# max:
# 0.0015694444444444447
# std:
# 0.0
# mean:
# 0.0015694444444444447
# median:
# 0.0015694444444444447
# 95% confidence interval for the mean:
# (nan,nan)
# using average of time series:
# stats on death:
# data: [0.01131666666666667]
# min:
# 0.01131666666666667
# max:
# 0.01131666666666667
# std:
# 0.0
# mean:
# 0.01131666666666667
# median:
# 0.01131666666666667
# 95% confidence interval for the mean:
# (nan,nan)
# using average of time series:
# stats on income:
# data: [0.6546956668352722]
# min:
# 0.6546956668352722
# max:
# 0.6546956668352722
# std:
# 0.0
# mean:
# 0.6546956668352722
# median:
# 0.6546956668352722
# 95% confidence interval for the mean:
# (nan,nan)
# using average of time series:
# stats on clumpiness:
# data: [0.5435606856165022]
# min:
# 0.5435606856165022
# max:
# 0.5435606856165022
# std:
# 0.0
# mean:
# 0.5435606856165022
# median:
# 0.5435606856165022
# 95% confidence interval for the mean:
# (nan,nan)
# using last of time series:
# stats on susceptible:
# data: [0.383]
# min:
# 0.383
# max:
# 0.383
# std:
# 0.0
# mean:
# 0.383
# median:
# 0.383
# 95% confidence interval for the mean:
# (nan,nan)
# using last of time series:
# stats on infected:
# data: [0.006]
# min:
# 0.006
# max:
# 0.006
# std:
# 0.0
# mean:
# 0.006
# median:
# 0.006
# 95% confidence interval for the mean:
# (nan,nan)
# using last of time series:
# stats on recovered:
# data: [0.58]
# min:
# 0.58
# max:
# 0.58
# std:
# 0.0
# mean:
# 0.58
# median:
# 0.58
# 95% confidence interval for the mean:
# (nan,nan)
# using last of time series:
# stats on hospitalization:
# data: [0.001]
# min:
# 0.001
# max:
# 0.001
# std:
# 0.0
# mean:
# 0.001
# median:
# 0.001
# 95% confidence interval for the mean:
# (nan,nan)
# using last of time series:
# stats on icu:
# data: [0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (nan,nan)
# using last of time series:
# stats on death:
# data: [0.015]
# min:
# 0.015
# max:
# 0.015
# std:
# 0.0
# mean:
# 0.015
# median:
# 0.015
# 95% confidence interval for the mean:
# (nan,nan)
# using last of time series:
# stats on income:
# data: [0.6403641881638846]
# min:
# 0.6403641881638846
# max:
# 0.6403641881638846
# std:
# 0.0
# mean:
# 0.6403641881638846
# median:
# 0.6403641881638846
# 95% confidence interval for the mean:
# (nan,nan)
# using last of time series:
# stats on clumpiness:
# data: [0.4246700143472023]
# min:
# 0.4246700143472023
# max:
# 0.4246700143472023
# std:
# 0.0
# mean:
# 0.4246700143472023
# median:
# 0.4246700143472023
# 95% confidence interval for the mean:
# (nan,nan)
# using peak of time series:
# stats on susceptible:
# data: [0.978]
# min:
# 0.978
# max:
# 0.978
# std:
# 0.0
# mean:
# 0.978
# median:
# 0.978
# 95% confidence interval for the mean:
# (nan,nan)
# using peak of time series:
# stats on infected:
# data: [0.253]
# min:
# 0.253
# max:
# 0.253
# std:
# 0.0
# mean:
# 0.253
# median:
# 0.253
# 95% confidence interval for the mean:
# (nan,nan)
# using peak of time series:
# stats on recovered:
# data: [0.58]
# min:
# 0.58
# max:
# 0.58
# std:
# 0.0
# mean:
# 0.58
# median:
# 0.58
# 95% confidence interval for the mean:
# (nan,nan)
# using peak of time series:
# stats on hospitalization:
# data: [0.05]
# min:
# 0.05
# max:
# 0.05
# std:
# 0.0
# mean:
# 0.05
# median:
# 0.05
# 95% confidence interval for the mean:
# (nan,nan)
# using peak of time series:
# stats on icu:
# data: [0.013]
# min:
# 0.013
# max:
# 0.013
# std:
# 0.0
# mean:
# 0.013
# median:
# 0.013
# 95% confidence interval for the mean:
# (nan,nan)
# using peak of time series:
# stats on death:
# data: [0.015]
# min:
# 0.015
# max:
# 0.015
# std:
# 0.0
# mean:
# 0.015
# median:
# 0.015
# 95% confidence interval for the mean:
# (nan,nan)
# using peak of time series:
# stats on income:
# data: [1.0]
# min:
# 1.0
# max:
# 1.0
# std:
# 0.0
# mean:
# 1.0
# median:
# 1.0
# 95% confidence interval for the mean:
# (nan,nan)
# using peak of time series:
# stats on clumpiness:
# data: [1.0]
# min:
# 1.0
# max:
# 1.0
# std:
# 0.0
# mean:
# 1.0
# median:
# 1.0
# 95% confidence interval for the mean:
# (nan,nan)
# (<function dict.items>, <function dict.items>, <function dict.items>)

# %%
import logging
def setLevel(level):
    logger1 = logging.getLogger()
    logger1.setLevel(level)
params.params['temperature'] = 1
params.params['num_communities'] = 12
seeds = [9675]
setLevel(logging.CRITICAL)
multiple_runs(params,population_size,simulation_cycles,seeds = seeds,fname = "duong10000-1", 
              do_print = True, 
              home_grid_height = 5, home_grid_width = 5, school_home_list = 
              [[(0,0),(0,1),(1,1),(2,1),(2,0),(1,0)],
               [(0,2),(0,3),(0,4),(1,3),(2,3),(2,2),(1,2)],
               [(1,4),(2,4),(3,4),(4,4)],
               [(3,3),(4,3),(4,2),(3,2),(3,1),(4,1),(4,0),(3,0)]],work_home_list = 
              [[(0,0),(0,1),(1,1),(2,1),(2,0),(1,0),
               (0,2),(0,3),(0,4),(1,3),(2,3),(2,2),(1,2),
               (1,4),(2,4),(3,4),(4,4),
               (3,3),(4,3),(4,2),(3,2),(3,1),(4,1),(4,0),(3,0)]],
              listeners = listeners)
# Out:
# Save these seeds if you want to rerun a scenario
# [9675]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-00f51f3a291e> in <module>
#      18                (1,4),(2,4),(3,4),(4,4),
#      19                (3,3),(4,3),(4,2),(3,2),(3,1),(4,1),(4,0),(3,0)]],
# ---> 20               listeners = listeners)
#
# /home/opencog/covid-simulation/covid19_sir/utils.py in multiple_runs(params, population_size, simulation_cycles, num_runs, seeds, debug, desired_stats, fname, listeners, do_print, home_grid_height, home_grid_width, work_home_list, school_home_list, temperature, zoomed_plot, zoomed_plot_ylim)
#      83         random.seed(s + 2)
#      84         model.reset_randomizer(s)
# ---> 85         setup_homophilic_layout(model,population_size,home_grid_height,home_grid_width,work_home_list,school_home_list)
#      86         #setup_grid_layout(model, population_size, home_grid_height,
#      87         #home_grid_width,work_height,work_width, school_height, school_width)
#
# /home/opencog/covid-simulation/covid19_sir/utils.py in setup_homophilic_layout(model, population_size, home_grid_height, home_grid_width, work_home_list, school_home_list, temperature)
#    1058         get_parameters().params['num_features'],home_district_in_position)
#    1059     model.hrf = hrf
# -> 1060     hrf.assign_features_to_families(family_factory.families,family_temperature)
#    1061     hrf.map_home_districts_to_blobs(home_grid_height,home_grid_width)
#    1062     hrf.assign_features_to_homes(home_room_temperature)
#
# /home/opencog/covid-simulation/covid19_sir/model/instantiation.py in assign_features_to_families(self, families, temperature)
#     253                         self.feature_vector[human] = tup_vec2
#     254                         self.vector_to_human[tup_vec2] = human
# --> 255                         keepset.remove(tup_vec1)
#     256                         #self.remove_tup_vec(distribution,tup_vec1)
#     257                         tup_vec1 = tup_vec2
#
# KeyError: (9.947816148668116, 7.267483904802351, 6.669186315556577, 6.152919752509189, -6.55992680689302, -9.068045967480847, 7.889113254211141, 4.042803595064284, 7.405577139005673, 5.251424815719696)

# %%
import logging
def setLevel(level):
    logger1 = logging.getLogger()
    logger1.setLevel(level)
params.params['temperature'] = 0
params.params['num_communities'] = 12
seeds = [9675]
setLevel(logging.CRITICAL)
multiple_runs(params,population_size,simulation_cycles,seeds = seeds,fname = "duong10000-1", 
              do_print = True, 
              home_grid_height = 5, home_grid_width = 5, school_home_list = 
              [[(0,0),(0,1),(1,1),(2,1),(2,0),(1,0)],
               [(0,2),(0,3),(0,4),(1,3),(2,3),(2,2),(1,2)],
               [(1,4),(2,4),(3,4),(4,4)],
               [(3,3),(4,3),(4,2),(3,2),(3,1),(4,1),(4,0),(3,0)]],work_home_list = 
              [[(0,0),(0,1),(1,1),(2,1),(2,0),(1,0),
               (0,2),(0,3),(0,4),(1,3),(2,3),(2,2),(1,2),
               (1,4),(2,4),(3,4),(4,4),
               (3,3),(4,3),(4,2),(3,2),(3,1),(4,1),(4,0),(3,0)]],
              listeners = listeners)

# %%
import logging
def setLevel(level):
    logger1 = logging.getLogger()
    logger1.setLevel(level)
params.params['temperature'] = -1
params.params['num_communities'] = 12
seeds = [9675]
setLevel(logging.CRITICAL)
multiple_runs(params,population_size,simulation_cycles,seeds = seeds,fname = "duong10000-1", 
              do_print = True, 
              home_grid_height = 5, home_grid_width = 5, school_home_list = 
              [[(0,0),(0,1),(1,1),(2,1),(2,0),(1,0)],
               [(0,2),(0,3),(0,4),(1,3),(2,3),(2,2),(1,2)],
               [(1,4),(2,4),(3,4),(4,4)],
               [(3,3),(4,3),(4,2),(3,2),(3,1),(4,1),(4,0),(3,0)]],work_home_list = 
              [[(0,0),(0,1),(1,1),(2,1),(2,0),(1,0),
               (0,2),(0,3),(0,4),(1,3),(2,3),(2,2),(1,2),
               (1,4),(2,4),(3,4),(4,4),
               (3,3),(4,3),(4,2),(3,2),(3,1),(4,1),(4,0),(3,0)]],
              listeners = listeners)
