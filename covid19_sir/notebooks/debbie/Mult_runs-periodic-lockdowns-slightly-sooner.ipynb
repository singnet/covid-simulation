# %%
import sys
sys.path.insert(0, '../..')
import copy
import numpy as np
from model.base import CovidModel, SimulationParameters, set_parameters, normal_ci
from utils import BasicStatistics, RemovePolicy, Propaganda, setup_city_layout, AddPolicyInfectedRate, confidence_interval, multiple_runs
from model.utils import SocialPolicy

# %%
listeners = [
    
["AddPolicy", SocialPolicy.LOCKDOWN_ELEMENTARY_SCHOOL, 0],
["AddPolicy", SocialPolicy.LOCKDOWN_MIDDLE_SCHOOL, 0],
["AddPolicy", SocialPolicy.LOCKDOWN_HIGH_SCHOOL, 0],
["AddPolicy", SocialPolicy.LOCKDOWN_RETAIL, 0],
["AddPolicy", SocialPolicy.LOCKDOWN_FACTORY, 0],
["AddPolicy", SocialPolicy.LOCKDOWN_OFFICE, 0],
["RemovePolicy", SocialPolicy.LOCKDOWN_ELEMENTARY_SCHOOL, 120],
["RemovePolicy", SocialPolicy.LOCKDOWN_MIDDLE_SCHOOL, 120],
["RemovePolicy", SocialPolicy.LOCKDOWN_HIGH_SCHOOL,120],
["RemovePolicy", SocialPolicy.LOCKDOWN_RETAIL, 120],
["RemovePolicy", SocialPolicy.LOCKDOWN_FACTORY, 120],
["RemovePolicy", SocialPolicy.LOCKDOWN_OFFICE,120],
["AddPolicy", SocialPolicy.LOCKDOWN_ELEMENTARY_SCHOOL, 150],
["AddPolicy", SocialPolicy.LOCKDOWN_MIDDLE_SCHOOL, 150],
["AddPolicy", SocialPolicy.LOCKDOWN_HIGH_SCHOOL, 150],
["AddPolicy", SocialPolicy.LOCKDOWN_RETAIL, 150],
["AddPolicy", SocialPolicy.LOCKDOWN_FACTORY, 150],
["AddPolicy", SocialPolicy.LOCKDOWN_OFFICE, 150],
["RemovePolicy", SocialPolicy.LOCKDOWN_ELEMENTARY_SCHOOL, 205],
["RemovePolicy", SocialPolicy.LOCKDOWN_MIDDLE_SCHOOL, 205],
["RemovePolicy", SocialPolicy.LOCKDOWN_HIGH_SCHOOL,205],
["RemovePolicy", SocialPolicy.LOCKDOWN_RETAIL, 205],
["RemovePolicy", SocialPolicy.LOCKDOWN_FACTORY, 205],
["RemovePolicy", SocialPolicy.LOCKDOWN_OFFICE,205]

]

# %%
common_parameters = SimulationParameters(
    mask_user_rate = 0.9, # 0.0,
    mask_efficacy = 0.6, #0.0,
    imune_rate = 0.01,
    initial_infection_rate = 0.01,
    hospitalization_capacity = 0.05,
    latency_period_shape = 3,
    latency_period_scale = 1, 
    incubation_period_shape = 6,
    incubation_period_scale = 1, 
    mild_period_duration_shape = 14,
    mild_period_duration_scale = 1,
    hospitalization_period_duration_shape = 12,
    hospitalization_period_duration_scale = 1,
    symptomatic_isolation_rate = 0.0,
    asymptomatic_contagion_probability = 0.1,
#    asymptomatic_contagion_probability = 0.05,
    risk_tolerance_mean = 0.7,
    risk_tolerance_stdev = 0.2,
    herding_behavior_mean = 0.7,
#    herding_behavior_mean = 0.1,
    herding_behavior_stdev = 0.2,
    allowed_restaurant_capacity = 0.25, #1.0, # valid values: {1.0, 0.50, 0.25}
    spreading_rate = normal_ci(2.41, 3.90, 20)
#    spreading_rate = normal_ci(0.5, 1.5, 20)
)

sc = 10

population_size = 1000
simulation_cycles = 360 # days
seed = 31415
np.random.seed(seed)

params = copy.deepcopy(common_parameters)

# %% [markdown]
# By changing the coverage of school and work districts over the home districts we can make the disease spread faster or slower as desired .
# def setup_grid_layout(model, population_size,
#         home_grid_height, home_grid_width,work_height,work_width, school_height, school_width):
#
#
# Makes a grid of homogeneous home districts, overlaid by school and work districts.
#
#
# home_grid_height is the number of home districts high the grid is, and
#
#
# home_grid_width is the nmber of home districts wide the grid is
#
#
# school height and work height are how many home districts high a school
#
#
# district and work are respectively, and the same for their length.
#
#
# each begins in grid 0,0 and cover the orignal home district grid.
#
#
# Persons assigned to the home districts are also assigned to the school
#
#
# and work districts that cover them. The parameters determine the amount
#
#
# of leakage across groups of people.  With parameters (10,10,1,1,1,1), you get 100
#
#
# completely separated districts with no leakage.  With parameters (6,6,2,2,3,3), illustrated below, you
#
#
# get a grid where every one is connected to everyone else, but there is a
#
#
# degree of separation.  For example, a person in home district (0,0) can be infected
#
#
# by a person in (5,5) but it would be bridged by three infections, slowing the
#
#
# virus down.  Larger sizes for work and school districts enable faster spread. Fastest
#
#
# spread occurs with parameters (1,1,1,1,1,1) or equivalently (10,10, 10,10,10,10)
#
#
# or any of the same number
#
#
# Since this is just a way to allocate human interactions, no label is needed and
#
#
# the grid need not be saved, for interactions to occur, although this informamtion
#
#
# may be useful for visualizations.

# %% [markdown]
# <img src="grids.jpg">

# %% [markdown]
#  Without locality, the defaults to multiple_run are :  home_grid_height = 1, home_grid_width = 1,work_height = 1, work_width =1, school_height=1, school_width=1.

# %%
import logging
def setLevel(level):
    logger1 = logging.getLogger()
    logger1.setLevel(level)

seeds = [5, 5348, 8388]
setLevel(logging.CRITICAL)
multiple_runs(params,population_size,simulation_cycles,seeds = seeds,fname = "duong0", do_print = True, listeners = listeners)
# Out:
# Save these seeds if you want to rerun a scenario
# [5, 5348, 8388]
# run with seed 5:
# run with seed 5348:
# run with seed 8388:
# using average of time series:
# stats on susceptible:
# data: [0.9233583333333333, 0.9697499999999999, 0.9049805555555556]
# min:
# 0.9049805555555556
# max:
# 0.9697499999999999
# std:
# 0.027253970935550428
# mean:
# 0.9326962962962962
# median:
# 0.9233583333333333
# 95% confidence interval for the mean:
# (0.8497778633476012,1.0156147292449913)
# using average of time series:
# stats on infected:
# data: [0.004850000000000001, 0.0016722222222222225, 0.0069277777777777775]
# min:
# 0.0016722222222222225
# max:
# 0.0069277777777777775
# std:
# 0.00216118013790553
# mean:
# 0.004483333333333333
# median:
# 0.004850000000000001
# 95% confidence interval for the mean:
# (-0.0020919165918516303,0.011058583258518297)
# using average of time series:
# stats on recovered:
# data: [0.05910555555555555, 0.020697222222222218, 0.07729166666666666]
# min:
# 0.020697222222222218
# max:
# 0.07729166666666666
# std:
# 0.023591113790214016
# mean:
# 0.05236481481481481
# median:
# 0.05910555555555555
# 95% confidence interval for the mean:
# (-0.019409613639105774,0.12413924326873539)
# using average of time series:
# stats on hospitalization:
# data: [0.0009944444444444445, 0.00035277777777777776, 0.001477777777777778]
# min:
# 0.00035277777777777776
# max:
# 0.001477777777777778
# std:
# 0.0004607930630050547
# mean:
# 0.0009416666666666667
# median:
# 0.0009944444444444445
# 95% confidence interval for the mean:
# (-0.0004602662402246777,0.002343599573558011)
# using average of time series:
# stats on icu:
# data: [0.0002027777777777778, 6.388888888888888e-05, 0.0005027777777777779]
# min:
# 6.388888888888888e-05
# max:
# 0.0005027777777777779
# std:
# 0.00018315554417152704
# mean:
# 0.0002564814814814815
# median:
# 0.0002027777777777778
# 95% confidence interval for the mean:
# (-0.0003007573423391763,0.0008137203053021392)
# using average of time series:
# stats on death:
# data: [0.0006861111111111113, 0.0008805555555555558, 0.002800000000000001]
# min:
# 0.0006861111111111113
# max:
# 0.002800000000000001
# std:
# 0.0009539742514491595
# mean:
# 0.001455555555555556
# median:
# 0.0008805555555555558
# 95% confidence interval for the mean:
# (-0.001446849022134329,0.004357960133245441)
# using average of time series:
# stats on income:
# data: [0.828557278208441, 0.8049019607843136, 0.8201685298102979]
# min:
# 0.8049019607843136
# max:
# 0.828557278208441
# std:
# 0.00979236251115416
# mean:
# 0.8178759229343507
# median:
# 0.8201685298102979
# 95% confidence interval for the mean:
# (0.7880832972575064,0.8476685486111951)
# using last of time series:
# stats on susceptible:
# data: [0.915, 0.969, 0.894]
# min:
# 0.894
# max:
# 0.969
# std:
# 0.03159113799786261
# mean:
# 0.926
# median:
# 0.915
# 95% confidence interval for the mean:
# (0.8298860185165954,1.0221139814834046)
# using last of time series:
# stats on infected:
# data: [0.0, 0.0, 0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (0.0,0.0)
# using last of time series:
# stats on recovered:
# data: [0.072, 0.023, 0.094]
# min:
# 0.023
# max:
# 0.094
# std:
# 0.029676028485406646
# mean:
# 0.063
# median:
# 0.072
# 95% confidence interval for the mean:
# (-0.02728738542246696,0.15328738542246695)
# using last of time series:
# stats on hospitalization:
# data: [0.0, 0.0, 0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (0.0,0.0)
# using last of time series:
# stats on icu:
# data: [0.0, 0.0, 0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (0.0,0.0)
# using last of time series:
# stats on death:
# data: [0.001, 0.001, 0.004]
# min:
# 0.001
# max:
# 0.004
# std:
# 0.001414213562373095
# mean:
# 0.002
# median:
# 0.001
# 95% confidence interval for the mean:
# (-0.0023026527299112743,0.006302652729911274)
# using last of time series:
# stats on income:
# data: [0.9984496124031008, 1.0, 0.9984756097560976]
# min:
# 0.9984496124031008
# max:
# 1.0
# std:
# 0.0007248097971718309
# mean:
# 0.9989750740530662
# median:
# 0.9984756097560976
# 95% confidence interval for the mean:
# (0.9967698874140449,1.0011802606920874)
# using peak of time series:
# stats on susceptible:
# data: [0.983, 0.982, 0.981]
# min:
# 0.981
# max:
# 0.983
# std:
# 0.0008164965809277268
# mean:
# 0.9819999999999999
# median:
# 0.982
# 95% confidence interval for the mean:
# (0.9795158622881561,0.9844841377118436)
# using peak of time series:
# stats on infected:
# data: [0.024, 0.017, 0.029]
# min:
# 0.017
# max:
# 0.029
# std:
# 0.004921607686744467
# mean:
# 0.023333333333333334
# median:
# 0.024
# 95% confidence interval for the mean:
# (0.00835966223277519,0.03830700443389148)
# using peak of time series:
# stats on recovered:
# data: [0.072, 0.023, 0.094]
# min:
# 0.023
# max:
# 0.094
# std:
# 0.029676028485406646
# mean:
# 0.063
# median:
# 0.072
# 95% confidence interval for the mean:
# (-0.02728738542246696,0.15328738542246695)
# using peak of time series:
# stats on hospitalization:
# data: [0.007, 0.006, 0.009]
# min:
# 0.006
# max:
# 0.009
# std:
# 0.0012472191289246467
# mean:
# 0.007333333333333333
# median:
# 0.007
# 95% confidence interval for the mean:
# (0.003538750299593869,0.011127916367072797)
# using peak of time series:
# stats on icu:
# data: [0.003, 0.002, 0.005]
# min:
# 0.002
# max:
# 0.005
# std:
# 0.0012472191289246471
# mean:
# 0.0033333333333333335
# median:
# 0.003
# 95% confidence interval for the mean:
# (-0.0004612497004061319,0.007127916367072799)
# using peak of time series:
# stats on death:
# data: [0.001, 0.001, 0.004]
# min:
# 0.001
# max:
# 0.004
# std:
# 0.001414213562373095
# mean:
# 0.002
# median:
# 0.001
# 95% confidence interval for the mean:
# (-0.0023026527299112743,0.006302652729911274)
# using peak of time series:
# stats on income:
# data: [1.0, 1.0, 1.0]
# min:
# 1.0
# max:
# 1.0
# std:
# 0.0
# mean:
# 1.0
# median:
# 1.0
# 95% confidence interval for the mean:
# (1.0,1.0)
# (<function dict.items>, <function dict.items>, <function dict.items>)

# %% [markdown]
#  Locality slows down the spread, with parameters home_grid_height = 6, home_grid_width = 6,
#                   work_height = 2, work_width =2, school_height=3, school_width=3

# %%
import logging
def setLevel(level):
    logger1 = logging.getLogger()
    logger1.setLevel(level)


setLevel(logging.CRITICAL)
seeds =[5, 5348, 8388]
multiple_runs(params,population_size,simulation_cycles,seeds = seeds,fname = "duong1", do_print = True, 
              listeners = listeners, home_grid_height = 6, home_grid_width = 6,
                  work_height = 2, work_width =2, school_height=3, school_width=3)
# Out:
# Save these seeds if you want to rerun a scenario
# [5, 5348, 8388]
# run with seed 5:
# run with seed 5348:
# run with seed 8388:
# using average of time series:
# stats on susceptible:
# data: [0.931210456210456, 0.7349305555555556, 0.6670916666666665]
# min:
# 0.6670916666666665
# max:
# 0.931210456210456
# std:
# 0.11199536162858269
# mean:
# 0.7777442261442261
# median:
# 0.7349305555555556
# 95% confidence interval for the mean:
# (0.4370056267773691,1.1184828255110832)
# using average of time series:
# stats on infected:
# data: [0.004600954600954601, 0.040669444444444446, 0.046983333333333335]
# min:
# 0.004600954600954601
# max:
# 0.046983333333333335
# std:
# 0.01866984252598575
# mean:
# 0.030751244126244127
# median:
# 0.040669444444444446
# 95% confidence interval for the mean:
# (-0.026050536770730288,0.08755302502321854)
# using average of time series:
# stats on recovered:
# data: [0.056368631368631364, 0.21251388888888886, 0.27741666666666664]
# min:
# 0.056368631368631364
# max:
# 0.27741666666666664
# std:
# 0.09276969447595636
# mean:
# 0.18209972897472895
# median:
# 0.21251388888888886
# 95% confidence interval for the mean:
# (-0.10014602924032626,0.4643454871897842)
# using average of time series:
# stats on hospitalization:
# data: [0.000901875901875902, 0.0061777777777777786, 0.006797222222222223]
# min:
# 0.000901875901875902
# max:
# 0.006797222222222223
# std:
# 0.0026452044714228495
# mean:
# 0.004625625300625301
# median:
# 0.0061777777777777786
# 95% confidence interval for the mean:
# (-0.0034222371601495003,0.012673487761400103)
# using average of time series:
# stats on icu:
# data: [0.00019702519702519703, 0.0013555555555555556, 0.0016944444444444448]
# min:
# 0.00019702519702519703
# max:
# 0.0016944444444444448
# std:
# 0.0006411190453843146
# mean:
# 0.0010823417323417323
# median:
# 0.0013555555555555556
# 95% confidence interval for the mean:
# (-0.0008682212407583561,0.0030329047054418207)
# using average of time series:
# stats on death:
# data: [0.0008269508269508272, 0.00588611111111111, 0.0005083333333333333]
# min:
# 0.0005083333333333333
# max:
# 0.00588611111111111
# std:
# 0.0024634464050554217
# mean:
# 0.002407131757131757
# median:
# 0.0008269508269508272
# 95% confidence interval for the mean:
# (-0.005087743615096873,0.009902007129360386)
# using average of time series:
# stats on income:
# data: [0.8366776593945543, 0.8070503238664672, 0.8299999999999998]
# min:
# 0.8070503238664672
# max:
# 0.8366776593945543
# std:
# 0.012688830521882737
# mean:
# 0.8245759944203405
# median:
# 0.8299999999999998
# 95% confidence interval for the mean:
# (0.7859710533160089,0.863180935524672)
# using last of time series:
# stats on susceptible:
# data: [0.926073926073926, 0.307, 0.246]
# min:
# 0.246
# max:
# 0.926073926073926
# std:
# 0.3072230588261002
# mean:
# 0.493024642024642
# median:
# 0.307
# 95% confidence interval for the mean:
# (-0.44168152111783665,1.4277308051671207)
# using last of time series:
# stats on infected:
# data: [0.0, 0.124, 0.016]
# min:
# 0.0
# max:
# 0.124
# std:
# 0.055071670474835695
# mean:
# 0.04666666666666667
# median:
# 0.016
# 95% confidence interval for the mean:
# (-0.12088530682148826,0.2142186401548216)
# using last of time series:
# stats on recovered:
# data: [0.06593406593406594, 0.551, 0.727]
# min:
# 0.06593406593406594
# max:
# 0.727
# std:
# 0.2795379381077366
# mean:
# 0.447978021978022
# median:
# 0.551
# 95% confidence interval for the mean:
# (-0.4024979630597411,1.298454007015785)
# using last of time series:
# stats on hospitalization:
# data: [0.0, 0.022, 0.008]
# min:
# 0.0
# max:
# 0.022
# std:
# 0.009092121131323903
# mean:
# 0.01
# median:
# 0.008
# 95% confidence interval for the mean:
# (-0.01766218684873152,0.03766218684873152)
# using last of time series:
# stats on icu:
# data: [0.0, 0.008, 0.003]
# min:
# 0.0
# max:
# 0.008
# std:
# 0.003299831645537222
# mean:
# 0.0036666666666666666
# median:
# 0.003
# 95% confidence interval for the mean:
# (-0.006372856369792975,0.01370618970312631)
# using last of time series:
# stats on death:
# data: [0.000999000999000999, 0.012, 0.003]
# min:
# 0.000999000999000999
# max:
# 0.012
# std:
# 0.004784534994495634
# mean:
# 0.005333000333000333
# median:
# 0.003
# 95% confidence interval for the mean:
# (-0.009223636021751056,0.019889636687751722)
# using last of time series:
# stats on income:
# data: [0.9984779299847792, 0.9880418535127056, 0.9969230769230769]
# min:
# 0.9880418535127056
# max:
# 0.9984779299847792
# std:
# 0.00459716566592193
# mean:
# 0.9944809534735205
# median:
# 0.9969230769230769
# 95% confidence interval for the mean:
# (0.9804943761074104,1.0084675308396305)
# using peak of time series:
# stats on susceptible:
# data: [0.983016983016983, 0.983, 0.975]
# min:
# 0.975
# max:
# 0.983016983016983
# std:
# 0.0037752454683615644
# mean:
# 0.9803389943389944
# median:
# 0.983
# 95% confidence interval for the mean:
# (0.968853055685377,0.9918249329926118)
# using peak of time series:
# stats on infected:
# data: [0.03496503496503497, 0.136, 0.145]
# min:
# 0.03496503496503497
# max:
# 0.145
# std:
# 0.04988515442701318
# mean:
# 0.10532167832167832
# median:
# 0.136
# 95% confidence interval for the mean:
# (-0.046450657616935925,0.25709401426029255)
# using peak of time series:
# stats on recovered:
# data: [0.06593406593406594, 0.551, 0.727]
# min:
# 0.06593406593406594
# max:
# 0.727
# std:
# 0.2795379381077366
# mean:
# 0.447978021978022
# median:
# 0.551
# 95% confidence interval for the mean:
# (-0.4024979630597411,1.298454007015785)
# using peak of time series:
# stats on hospitalization:
# data: [0.006993006993006993, 0.027, 0.021]
# min:
# 0.006993006993006993
# max:
# 0.027
# std:
# 0.008383022673368002
# mean:
# 0.018331002331002332
# median:
# 0.021
# 95% confidence interval for the mean:
# (-0.007173798605816316,0.04383580326782098)
# using peak of time series:
# stats on icu:
# data: [0.002997002997002997, 0.008, 0.008]
# min:
# 0.002997002997002997
# max:
# 0.008
# std:
# 0.00235843540471677
# mean:
# 0.006332334332334332
# median:
# 0.008
# 95% confidence interval for the mean:
# (-0.000843051905226661,0.013507720569895326)
# using peak of time series:
# stats on death:
# data: [0.000999000999000999, 0.012, 0.003]
# min:
# 0.000999000999000999
# max:
# 0.012
# std:
# 0.004784534994495634
# mean:
# 0.005333000333000333
# median:
# 0.003
# 95% confidence interval for the mean:
# (-0.009223636021751056,0.019889636687751722)
# using peak of time series:
# stats on income:
# data: [1.0, 1.0, 1.0]
# min:
# 1.0
# max:
# 1.0
# std:
# 0.0
# mean:
# 1.0
# median:
# 1.0
# 95% confidence interval for the mean:
# (1.0,1.0)
# (<function dict.items>, <function dict.items>, <function dict.items>)

# %%
import logging
def setLevel(level):
    logger1 = logging.getLogger()
    logger1.setLevel(level)


setLevel(logging.CRITICAL)
seeds = [5, 5348, 8388]
multiple_runs(params,population_size,simulation_cycles,seeds = seeds,fname = "duong2", do_print = True, 
              listeners = listeners, home_grid_height = 3, home_grid_width = 4,
                  work_height = 1, work_width =2, school_height=2, school_width=1)
# Out:
# Save these seeds if you want to rerun a scenario
# [5, 5348, 8388]
# run with seed 5:
# run with seed 5348:
# run with seed 8388:
# using average of time series:
# stats on susceptible:
# data: [0.3872433122433122, 0.22979166666666664, 0.24992245485764925]
# min:
# 0.22979166666666664
# max:
# 0.3872433122433122
# std:
# 0.06996291652735073
# mean:
# 0.288985811255876
# median:
# 0.24992245485764925
# 95% confidence interval for the mean:
# (0.07612819073933333,0.5018434317724187)
# using average of time series:
# stats on infected:
# data: [0.048426573426573416, 0.05623333333333333, 0.05319596765259776]
# min:
# 0.048426573426573416
# max:
# 0.05623333333333333
# std:
# 0.0032131364359374377
# mean:
# 0.05261862480416817
# median:
# 0.05319596765259776
# 95% confidence interval for the mean:
# (0.04284286630100066,0.06239438330733568)
# using average of time series:
# stats on recovered:
# data: [0.5444111444111445, 0.6947694444444443, 0.6716766367563974]
# min:
# 0.5444111444111445
# max:
# 0.6947694444444443
# std:
# 0.06611219562876142
# mean:
# 0.6369524085373288
# median:
# 0.6716766367563974
# 95% confidence interval for the mean:
# (0.43581035575911237,0.8380944613155452)
# using average of time series:
# stats on hospitalization:
# data: [0.008841158841158842, 0.00900277777777778, 0.008283482884679295]
# min:
# 0.008283482884679295
# max:
# 0.00900277777777778
# std:
# 0.00030813205977429985
# mean:
# 0.008709139834538639
# median:
# 0.008841158841158842
# 95% confidence interval for the mean:
# (0.0077716680951668525,0.009646611573910426)
# using average of time series:
# stats on icu:
# data: [0.0022921522921522924, 0.0025638888888888894, 0.0018001550902847013]
# min:
# 0.0018001550902847013
# max:
# 0.0025638888888888894
# std:
# 0.00031608566697124475
# mean:
# 0.002218732090441961
# median:
# 0.0022921522921522924
# 95% confidence interval for the mean:
# (0.0012570620187750494,0.0031804021621088725)
# using average of time series:
# stats on death:
# data: [0.01392496392496392, 0.014205555555555553, 0.0132408330563864]
# min:
# 0.0132408330563864
# max:
# 0.014205555555555553
# std:
# 0.0004051688549100213
# mean:
# 0.013790450845635288
# median:
# 0.01392496392496392
# 95% confidence interval for the mean:
# (0.012557750971983734,0.015023150719286843)
# using average of time series:
# stats on income:
# data: [0.9839448751076658, 0.9856644546537349, 0.982805255023184]
# min:
# 0.982805255023184
# max:
# 0.9856644546537349
# std:
# 0.0011752404141543485
# mean:
# 0.9841381949281948
# median:
# 0.9839448751076658
# 95% confidence interval for the mean:
# (0.9805626024499428,0.9877137874064468)
# using last of time series:
# stats on susceptible:
# data: [0.2627372627372627, 0.118, 0.15653040877367896]
# min:
# 0.118
# max:
# 0.2627372627372627
# std:
# 0.0612039971949765
# mean:
# 0.17908922383698056
# median:
# 0.15653040877367896
# 95% confidence interval for the mean:
# (-0.00711995462016532,0.36529840229412647)
# using last of time series:
# stats on infected:
# data: [0.0, 0.0, 0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (0.0,0.0)
# using last of time series:
# stats on recovered:
# data: [0.7112887112887113, 0.859, 0.8145563310069791]
# min:
# 0.7112887112887113
# max:
# 0.859
# std:
# 0.061876279612885283
# mean:
# 0.7949483474318968
# median:
# 0.8145563310069791
# 95% confidence interval for the mean:
# (0.6066937934687823,0.9832029013950113)
# using last of time series:
# stats on hospitalization:
# data: [0.0, 0.0, 0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (0.0,0.0)
# using last of time series:
# stats on icu:
# data: [0.0, 0.0, 0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (0.0,0.0)
# using last of time series:
# stats on death:
# data: [0.01998001998001998, 0.018, 0.01694915254237288]
# min:
# 0.01694915254237288
# max:
# 0.01998001998001998
# std:
# 0.0012565789945133304
# mean:
# 0.018309724174130956
# median:
# 0.018
# 95% confidence interval for the mean:
# (0.014486664358455408,0.022132783989806504)
# using last of time series:
# stats on income:
# data: [0.9767441860465116, 0.9816232771822359, 0.9783616692426584]
# min:
# 0.9767441860465116
# max:
# 0.9816232771822359
# std:
# 0.0020292272352913886
# mean:
# 0.978909710823802
# median:
# 0.9783616692426584
# 95% confidence interval for the mean:
# (0.9727359190176438,0.9850835026299601)
# using peak of time series:
# stats on susceptible:
# data: [0.987012987012987, 0.98, 0.9730807577268196]
# min:
# 0.9730807577268196
# max:
# 0.987012987012987
# std:
# 0.0056878517069436215
# mean:
# 0.9800312482466021
# median:
# 0.98
# 95% confidence interval for the mean:
# (0.9627263295799015,0.9973361669133028)
# using peak of time series:
# stats on infected:
# data: [0.2857142857142857, 0.332, 0.3349950149551346]
# min:
# 0.2857142857142857
# max:
# 0.3349950149551346
# std:
# 0.022558387787226776
# mean:
# 0.31756976688980676
# median:
# 0.332
# 95% confidence interval for the mean:
# (0.24893734009265656,0.38620219368695696)
# using peak of time series:
# stats on recovered:
# data: [0.7112887112887113, 0.859, 0.8145563310069791]
# min:
# 0.7112887112887113
# max:
# 0.859
# std:
# 0.061876279612885283
# mean:
# 0.7949483474318968
# median:
# 0.8145563310069791
# 95% confidence interval for the mean:
# (0.6066937934687823,0.9832029013950113)
# using peak of time series:
# stats on hospitalization:
# data: [0.05094905094905095, 0.05, 0.05084745762711865]
# min:
# 0.05
# max:
# 0.05094905094905095
# std:
# 0.0004254674993093951
# mean:
# 0.05059883619205654
# median:
# 0.05084745762711865
# 95% confidence interval for the mean:
# (0.04930437901380673,0.05189329337030635)
# using peak of time series:
# stats on icu:
# data: [0.014985014985014986, 0.02, 0.015952143569292122]
# min:
# 0.014985014985014986
# max:
# 0.02
# std:
# 0.002172314538373843
# mean:
# 0.016979052851435705
# median:
# 0.015952143569292122
# 95% confidence interval for the mean:
# (0.010369927237425835,0.023588178465445572)
# using peak of time series:
# stats on death:
# data: [0.01998001998001998, 0.018, 0.01694915254237288]
# min:
# 0.01694915254237288
# max:
# 0.01998001998001998
# std:
# 0.0012565789945133304
# mean:
# 0.018309724174130956
# median:
# 0.018
# 95% confidence interval for the mean:
# (0.014486664358455408,0.022132783989806504)
# using peak of time series:
# stats on income:
# data: [1.0, 1.0, 1.0]
# min:
# 1.0
# max:
# 1.0
# std:
# 0.0
# mean:
# 1.0
# median:
# 1.0
# 95% confidence interval for the mean:
# (1.0,1.0)
# (<function dict.items>, <function dict.items>, <function dict.items>)

# %%
import logging
def setLevel(level):
    logger1 = logging.getLogger()
    logger1.setLevel(level)


setLevel(logging.CRITICAL)
seeds = [5, 5348, 8388]
multiple_runs(params,population_size,simulation_cycles,seeds = seeds,fname = "duong3", do_print = True, 
              listeners = listeners, home_grid_height = 3, home_grid_width = 4,
                  work_height = 1, work_width =1, school_height=1, school_width=1)
# Out:
# Save these seeds if you want to rerun a scenario
# [5, 5348, 8388]
# run with seed 5:
# run with seed 5348:
# run with seed 8388:
# using average of time series:
# stats on susceptible:
# data: [0.3515484515484516, 0.4252888888888888, 0.3738317238317238]
# min:
# 0.3515484515484516
# max:
# 0.4252888888888888
# std:
# 0.030879759927337016
# mean:
# 0.38355635475635474
# median:
# 0.3738317238317238
# 95% confidence interval for the mean:
# (0.2896066947577546,0.4775060147549549)
# using average of time series:
# stats on infected:
# data: [0.0497002997002997, 0.04637222222222222, 0.04928959928959929]
# min:
# 0.04637222222222222
# max:
# 0.0497002997002997
# std:
# 0.001481585617606792
# mean:
# 0.04845404040404041
# median:
# 0.04928959928959929
# 95% confidence interval for the mean:
# (0.04394641258049153,0.05296166822758929)
# using average of time series:
# stats on recovered:
# data: [0.5806360306360305, 0.5079527777777778, 0.5627289377289377]
# min:
# 0.5079527777777778
# max:
# 0.5806360306360305
# std:
# 0.030919154296029316
# mean:
# 0.5504392487142488
# median:
# 0.5627289377289377
# 95% confidence interval for the mean:
# (0.45636973391259283,0.6445087635159047)
# using average of time series:
# stats on hospitalization:
# data: [0.007858807858807857, 0.008752777777777778, 0.008028083028083027]
# min:
# 0.007858807858807857
# max:
# 0.008752777777777778
# std:
# 0.00038773111805754154
# mean:
# 0.008213222888222889
# median:
# 0.008028083028083027
# 95% confidence interval for the mean:
# (0.007033576194139133,0.009392869582306644)
# using average of time series:
# stats on icu:
# data: [0.002150627150627151, 0.0025194444444444444, 0.0018981018981018979]
# min:
# 0.0018981018981018979
# max:
# 0.0025194444444444444
# std:
# 0.0002551386897959387
# mean:
# 0.0021893911643911645
# median:
# 0.002150627150627151
# 95% confidence interval for the mean:
# (0.001413148304497795,0.002965634024284534)
# using average of time series:
# stats on death:
# data: [0.010123210123210121, 0.01238611111111111, 0.0061577311577311585]
# min:
# 0.0061577311577311585
# max:
# 0.01238611111111111
# std:
# 0.0025741980660729754
# mean:
# 0.00955568413068413
# median:
# 0.010123210123210121
# 95% confidence interval for the mean:
# (0.001723854037260662,0.0173875142241076)
# using average of time series:
# stats on income:
# data: [0.9862968860580326, 0.9886379104985537, 0.9928342606643061]
# min:
# 0.9862968860580326
# max:
# 0.9928342606643061
# std:
# 0.002704461681647128
# mean:
# 0.9892563524069642
# median:
# 0.9886379104985537
# 95% confidence interval for the mean:
# (0.9810282037403983,0.99748450107353)
# using last of time series:
# stats on susceptible:
# data: [0.21978021978021978, 0.301, 0.22977022977022976]
# min:
# 0.21978021978021978
# max:
# 0.301
# std:
# 0.03616341485463476
# mean:
# 0.2501834831834832
# median:
# 0.22977022977022976
# 95% confidence interval for the mean:
# (0.14015864691610305,0.3602083194508634)
# using last of time series:
# stats on infected:
# data: [0.0, 0.0, 0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (0.0,0.0)
# using last of time series:
# stats on recovered:
# data: [0.7582417582417582, 0.673, 0.7542457542457542]
# min:
# 0.673
# max:
# 0.7582417582417582
# std:
# 0.03927537817774489
# mean:
# 0.7284958374958376
# median:
# 0.7542457542457542
# 95% confidence interval for the mean:
# (0.6090030553369647,0.8479886196547104)
# using last of time series:
# stats on hospitalization:
# data: [0.0, 0.0, 0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (0.0,0.0)
# using last of time series:
# stats on icu:
# data: [0.0, 0.0, 0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (0.0,0.0)
# using last of time series:
# stats on death:
# data: [0.013986013986013986, 0.018, 0.007992007992007992]
# min:
# 0.007992007992007992
# max:
# 0.018
# std:
# 0.004112313428509378
# mean:
# 0.013326007326007326
# median:
# 0.013986013986013986
# 95% confidence interval for the mean:
# (0.0008145613392103821,0.025837453312804272)
# using last of time series:
# stats on income:
# data: [0.9808917197452229, 0.9831546707503829, 0.9908952959028832]
# min:
# 0.9808917197452229
# max:
# 0.9908952959028832
# std:
# 0.004283168102460073
# mean:
# 0.9849805621328297
# median:
# 0.9831546707503829
# 95% confidence interval for the mean:
# (0.971949301919348,0.9980118223463114)
# using peak of time series:
# stats on susceptible:
# data: [0.978021978021978, 0.98, 0.983016983016983]
# min:
# 0.978021978021978
# max:
# 0.983016983016983
# std:
# 0.0020538536237583458
# mean:
# 0.9803463203463204
# median:
# 0.98
# 95% confidence interval for the mean:
# (0.9740976043558774,0.9865950363367634)
# using peak of time series:
# stats on infected:
# data: [0.22577422577422576, 0.193, 0.18681318681318682]
# min:
# 0.18681318681318682
# max:
# 0.22577422577422576
# std:
# 0.01709577299747918
# mean:
# 0.20186247086247086
# median:
# 0.193
# 95% confidence interval for the mean:
# (0.14984969406932797,0.25387524765561376)
# using peak of time series:
# stats on recovered:
# data: [0.7582417582417582, 0.673, 0.7542457542457542]
# min:
# 0.673
# max:
# 0.7582417582417582
# std:
# 0.03927537817774489
# mean:
# 0.7284958374958376
# median:
# 0.7542457542457542
# 95% confidence interval for the mean:
# (0.6090030553369647,0.8479886196547104)
# using peak of time series:
# stats on hospitalization:
# data: [0.03896103896103896, 0.045, 0.03496503496503497]
# min:
# 0.03496503496503497
# max:
# 0.045
# std:
# 0.004124959550227803
# mean:
# 0.03964202464202465
# median:
# 0.03896103896103896
# 95% confidence interval for the mean:
# (0.027092103652878508,0.052191945631170786)
# using peak of time series:
# stats on icu:
# data: [0.013986013986013986, 0.015, 0.013986013986013986]
# min:
# 0.013986013986013986
# max:
# 0.015
# std:
# 0.000477997591011885
# mean:
# 0.014324009324009323
# median:
# 0.013986013986013986
# 95% confidence interval for the mean:
# (0.012869732760286398,0.01577828588773225)
# using peak of time series:
# stats on death:
# data: [0.013986013986013986, 0.018, 0.007992007992007992]
# min:
# 0.007992007992007992
# max:
# 0.018
# std:
# 0.004112313428509378
# mean:
# 0.013326007326007326
# median:
# 0.013986013986013986
# 95% confidence interval for the mean:
# (0.0008145613392103821,0.025837453312804272)
# using peak of time series:
# stats on income:
# data: [1.0, 1.0, 1.0]
# min:
# 1.0
# max:
# 1.0
# std:
# 0.0
# mean:
# 1.0
# median:
# 1.0
# 95% confidence interval for the mean:
# (1.0,1.0)
# (<function dict.items>, <function dict.items>, <function dict.items>)

# %%
import logging
def setLevel(level):
    logger1 = logging.getLogger()
    logger1.setLevel(level)


setLevel(logging.CRITICAL)
seeds = [5, 5348, 8388]
multiple_runs(params,population_size,simulation_cycles,seeds = seeds,fname = "duong4", do_print = True, 
              listeners = listeners, home_grid_height = 10, home_grid_width = 10,
                  work_height = 1, work_width =1, school_height=1, school_width=1)
# Out:
# Save these seeds if you want to rerun a scenario
# [5, 5348, 8388]
# run with seed 5:
# run with seed 5348:
# run with seed 8388:
# using average of time series:
# stats on susceptible:
# data: [0.8979527777777777, 0.9141027777777779, 0.9568444444444443]
# min:
# 0.8979527777777777
# max:
# 0.9568444444444443
# std:
# 0.024845972113139585
# mean:
# 0.9229666666666666
# median:
# 0.9141027777777779
# 95% confidence interval for the mean:
# (0.847374413428399,0.9985589199049342)
# using average of time series:
# stats on infected:
# data: [0.007258333333333334, 0.005244444444444445, 0.0022166666666666667]
# min:
# 0.0022166666666666667
# max:
# 0.007258333333333334
# std:
# 0.002072078653220074
# mean:
# 0.004906481481481482
# median:
# 0.005244444444444445
# 95% confidence interval for the mean:
# (-0.0013976829750577749,0.01121064593802074)
# using average of time series:
# stats on recovered:
# data: [0.08443333333333333, 0.07018888888888888, 0.028938888888888896]
# min:
# 0.028938888888888896
# max:
# 0.08443333333333333
# std:
# 0.023532719684464846
# mean:
# 0.06118703703703704
# median:
# 0.07018888888888888
# 95% confidence interval for the mean:
# (-0.0104097311502893,0.1327838052243634)
# using average of time series:
# stats on hospitalization:
# data: [0.0015277777777777779, 0.0007250000000000001, 0.0003777777777777778]
# min:
# 0.0003777777777777778
# max:
# 0.0015277777777777779
# std:
# 0.0004816078893893715
# mean:
# 0.0008768518518518519
# median:
# 0.0007250000000000001
# 95% confidence interval for the mean:
# (-0.0005884088097350616,0.0023421125134387654)
# using average of time series:
# stats on icu:
# data: [0.00038333333333333334, 0.0001527777777777778, 0.00014722222222222223]
# min:
# 0.00014722222222222223
# max:
# 0.00038333333333333334
# std:
# 0.00011001776886040082
# mean:
# 0.00022777777777777778
# median:
# 0.0001527777777777778
# 95% confidence interval for the mean:
# (-0.0001069441242888552,0.0005624996798444107)
# using average of time series:
# stats on death:
# data: [0.0013555555555555558, 0.0024638888888888887, 0.0]
# min:
# 0.0
# max:
# 0.0024638888888888887
# std:
# 0.0010075648365553583
# mean:
# 0.0012731481481481483
# median:
# 0.0013555555555555558
# 95% confidence interval for the mean:
# (-0.0017923022971812787,0.004338598593477575)
# using average of time series:
# stats on income:
# data: [0.9979545454545454, 0.9976526965562054, 1.0]
# min:
# 0.9976526965562054
# max:
# 1.0
# std:
# 0.0010426904575397476
# mean:
# 0.9985357473369169
# median:
# 0.9979545454545454
# 95% confidence interval for the mean:
# (0.9953634294756332,1.0017080651982007)
# using last of time series:
# stats on susceptible:
# data: [0.885, 0.909, 0.955]
# min:
# 0.885
# max:
# 0.955
# std:
# 0.029044027881055933
# mean:
# 0.9163333333333333
# median:
# 0.909
# 95% confidence interval for the mean:
# (0.8279687686205279,1.0046978980461387)
# using last of time series:
# stats on infected:
# data: [0.0, 0.0, 0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (0.0,0.0)
# using last of time series:
# stats on recovered:
# data: [0.104, 0.08, 0.033]
# min:
# 0.033
# max:
# 0.104
# std:
# 0.029488227406128626
# mean:
# 0.07233333333333333
# median:
# 0.08
# 95% confidence interval for the mean:
# (-0.017382679527071704,0.16204934619373837)
# using last of time series:
# stats on hospitalization:
# data: [0.0, 0.0, 0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (0.0,0.0)
# using last of time series:
# stats on icu:
# data: [0.0, 0.0, 0.0]
# min:
# 0.0
# max:
# 0.0
# std:
# 0.0
# mean:
# 0.0
# median:
# 0.0
# 95% confidence interval for the mean:
# (0.0,0.0)
# using last of time series:
# stats on death:
# data: [0.002, 0.003, 0.0]
# min:
# 0.0
# max:
# 0.003
# std:
# 0.0012472191289246471
# mean:
# 0.0016666666666666668
# median:
# 0.002
# 95% confidence interval for the mean:
# (-0.002127916367072799,0.005461249700406132)
# using last of time series:
# stats on income:
# data: [0.996969696969697, 0.9970760233918129, 1.0]
# min:
# 0.996969696969697
# max:
# 1.0
# std:
# 0.0014041082962637098
# mean:
# 0.9980152401205032
# median:
# 0.9970760233918129
# 95% confidence interval for the mean:
# (0.9937433320051035,1.002287148235903)
# using peak of time series:
# stats on susceptible:
# data: [0.979, 0.977, 0.98]
# min:
# 0.977
# max:
# 0.98
# std:
# 0.0012472191289246482
# mean:
# 0.9786666666666667
# median:
# 0.979
# 95% confidence interval for the mean:
# (0.9748720836329272,0.9824612497004062)
# using peak of time series:
# stats on infected:
# data: [0.035, 0.04, 0.015]
# min:
# 0.015
# max:
# 0.04
# std:
# 0.010801234497346435
# mean:
# 0.030000000000000002
# median:
# 0.035
# 95% confidence interval for the mean:
# (-0.0028620530398780035,0.062862053039878)
# using peak of time series:
# stats on recovered:
# data: [0.104, 0.08, 0.033]
# min:
# 0.033
# max:
# 0.104
# std:
# 0.029488227406128626
# mean:
# 0.07233333333333333
# median:
# 0.08
# 95% confidence interval for the mean:
# (-0.017382679527071704,0.16204934619373837)
# using peak of time series:
# stats on hospitalization:
# data: [0.008, 0.008, 0.004]
# min:
# 0.004
# max:
# 0.008
# std:
# 0.0018856180831641268
# mean:
# 0.006666666666666667
# median:
# 0.008
# 95% confidence interval for the mean:
# (0.0009297963601182999,0.012403536973215034)
# using peak of time series:
# stats on icu:
# data: [0.003, 0.003, 0.003]
# min:
# 0.003
# max:
# 0.003
# std:
# 4.336808689942018e-19
# mean:
# 0.0030000000000000005
# median:
# 0.003
# 95% confidence interval for the mean:
# (0.002999999999999999,0.003000000000000002)
# using peak of time series:
# stats on death:
# data: [0.002, 0.003, 0.0]
# min:
# 0.0
# max:
# 0.003
# std:
# 0.0012472191289246471
# mean:
# 0.0016666666666666668
# median:
# 0.002
# 95% confidence interval for the mean:
# (-0.002127916367072799,0.005461249700406132)
# using peak of time series:
# stats on income:
# data: [1.0, 1.0, 1.0]
# min:
# 1.0
# max:
# 1.0
# std:
# 0.0
# mean:
# 1.0
# median:
# 1.0
# 95% confidence interval for the mean:
# (1.0,1.0)
# (<function dict.items>, <function dict.items>, <function dict.items>)
