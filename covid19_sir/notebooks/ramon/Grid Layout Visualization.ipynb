# %% [markdown]
# # Grid Layout Visualization

# %% [markdown]
# This code is meant to run inside the docker container. If you're running it locally, please:
# 1. Substitute the files **ModularVisualization.py** and **ChartModule.js** by the ones in the _lib_ subdirectory provided (the original versions are also in the directory if needed);
# 2. Uncomment and run the following cell:

# %%
# import sys
# sys.path.insert(0, '../..')

# %% [markdown]
# The code in this notebook requires a few changes in the code of the imported libraries, namely:
# - ModularVisualization.py -> class ModularServer -> \_\_init\_\_() : to allow the server to run the already instantiated object of the CovidModel class (instead of instantiating it inside the server). **WARNING: This also disables the "Reset" button once the simulation is running.**
# - ChartModule.js -> var ChartModule -> chartOptions: to improve visualizations by adding axes labels and fixing the manually defined maximum value of 900 to the chart.
#
# These changes will be made automatically by the next cell:

# %%
# !cp ./lib/ChartModule.js /opt/singnet/covid-simulation/covid19_sir/notebooks/ramon/lib/ChartModule.js
# Out:
# cp: cannot create regular file '/opt/singnet/covid-simulation/covid19_sir/notebooks/ramon/lib/ChartModule.js': No such file or directory

# %%
# !find / -type f -name ChartModule.js
# Out:
# find: ‘/run/docker’: Permission denied
# find: ‘/run/containerd’: Permission denied
# find: ‘/run/gdm3’: Permission denied
# find: ‘/run/udisks2’: Permission denied
# find: ‘/run/cups/certs’: Permission denied
# find: ‘/run/sudo’: Permission denied
# find: ‘/run/openvpn-server’: Permission denied
# find: ‘/run/openvpn-client’: Permission denied
# find: ‘/run/systemd/unit-root’: Permission denied
# find: ‘/run/systemd/resolve/netif’: Permission denied
# find: ‘/run/systemd/inaccessible’: Permission denied
# find: ‘/proc/tty/driver’: Permission denied
# find: ‘/proc/1/task/1/fd’: Permission denied
# find: ‘/proc/1/task/1/fdinfo’: Permission denied
# find: ‘/proc/1/task/1/ns’: Permission denied
# find: ‘/proc/1/fd’: Permission denied
# find: ‘/proc/1/map_files’: Permission denied
# find: ‘/proc/1/fdinfo’: Permission denied
# find: ‘/proc/1/ns’: Permission denied
# find: ‘/proc/2/task/2/fd’: Permission denied
# find: ‘/proc/2/task/2/fdinfo’: Permission denied
# find: ‘/proc/2/task/2/ns’: Permission denied
# find: ‘/proc/2/fd’: Permission denied
# find: ‘/proc/2/map_files’: Permission denied
# find: ‘/proc/2/fdinfo’: Permission denied
# find: ‘/proc/2/ns’: Permission denied
# find: ‘/proc/3/task/3/fd’: Permission denied
# find: ‘/proc/3/task/3/fdinfo’: Permission denied
# find: ‘/proc/3/task/3/ns’: Permission denied
# find: ‘/proc/3/fd’: Permission denied
# find: ‘/proc/3/map_files’: Permission denied
# find: ‘/proc/3/fdinfo’: Permission denied
# find: ‘/proc/3/ns’: Permission denied
# find: ‘/proc/4/task/4/fd’: Permission denied
# find: ‘/proc/4/task/4/fdinfo’: Permission denied
# find: ‘/proc/4/task/4/ns’: Permission denied
# find: ‘/proc/4/fd’: Permission denied
# find: ‘/proc/4/map_files’: Permission denied
# find: ‘/proc/4/fdinfo’: Permission denied
# find: ‘/proc/4/ns’: Permission denied
# find: ‘/proc/6/task/6/fd’: Permission denied
# find: ‘/proc/6/task/6/fdinfo’: Permission denied
# find: ‘/proc/6/task/6/ns’: Permission denied
# find: ‘/proc/6/fd’: Permission denied
# find: ‘/proc/6/map_files’: Permission denied
# find: ‘/proc/6/fdinfo’: Permission denied
# find: ‘/proc/6/ns’: Permission denied
# find: ‘/proc/9/task/9/fd’: Permission denied
# find: ‘/proc/9/task/9/fdinfo’: Permission denied
# find: ‘/proc/9/task/9/ns’: Permission denied
# find: ‘/proc/9/fd’: Permission denied
# find: ‘/proc/9/map_files’: Permission denied
# find: ‘/proc/9/fdinfo’: Permission denied
# find: ‘/proc/9/ns’: Permission denied
# find: ‘/proc/10/task/10/fd’: Permission denied
# find: ‘/proc/10/task/10/fdinfo’: Permission denied
# find: ‘/proc/10/task/10/ns’: Permission denied
# find: ‘/proc/10/fd’: Permission denied
# find: ‘/proc/10/map_files’: Permission denied
# find: ‘/proc/10/fdinfo’: Permission denied
# find: ‘/proc/10/ns’: Permission denied
# find: ‘/proc/11/task/11/fd’: Permission denied
# find: ‘/proc/11/task/11/fdinfo’: Permission denied
# find: ‘/proc/11/task/11/ns’: Permission denied
# find: ‘/proc/11/fd’: Permission denied
# find: ‘/proc/11/map_files’: Permission denied
# find: ‘/proc/11/fdinfo’: Permission denied
# find: ‘/proc/11/ns’: Permission denied
# find: ‘/proc/12/task/12/fd’: Permission denied
# find: ‘/proc/12/task/12/fdinfo’: Permission denied
# find: ‘/proc/12/task/12/ns’: Permission denied
# find: ‘/proc/12/fd’: Permission denied
# find: ‘/proc/12/map_files’: Permission denied
# find: ‘/proc/12/fdinfo’: Permission denied
# find: ‘/proc/12/ns’: Permission denied
# find: ‘/proc/13/task/13/fd’: Permission denied
# find: ‘/proc/13/task/13/fdinfo’: Permission denied
# find: ‘/proc/13/task/13/ns’: Permission denied
# find: ‘/proc/13/fd’: Permission denied
# find: ‘/proc/13/map_files’: Permission denied
# find: ‘/proc/13/fdinfo’: Permission denied
# find: ‘/proc/13/ns’: Permission denied
# find: ‘/proc/14/task/14/fd’: Permission denied
# find: ‘/proc/14/task/14/fdinfo’: Permission denied
# find: ‘/proc/14/task/14/ns’: Permission denied
# find: ‘/proc/14/fd’: Permission denied
# find: ‘/proc/14/map_files’: Permission denied
# find: ‘/proc/14/fdinfo’: Permission denied
# find: ‘/proc/14/ns’: Permission denied
# find: ‘/proc/15/task/15/fd’: Permission denied
# find: ‘/proc/15/task/15/fdinfo’: Permission denied
# find: ‘/proc/15/task/15/ns’: Permission denied
# find: ‘/proc/15/fd’: Permission denied
# find: ‘/proc/15/map_files’: Permission denied
# find: ‘/proc/15/fdinfo’: Permission denied
# find: ‘/proc/15/ns’: Permission denied
# find: ‘/proc/16/task/16/fd’: Permission denied
# find: ‘/proc/16/task/16/fdinfo’: Permission denied
# find: ‘/proc/16/task/16/ns’: Permission denied
# find: ‘/proc/16/fd’: Permission denied
# find: ‘/proc/16/map_files’: Permission denied
# find: ‘/proc/16/fdinfo’: Permission denied
# find: ‘/proc/16/ns’: Permission denied
# find: ‘/proc/17/task/17/fd’: Permission denied
# find: ‘/proc/17/task/17/fdinfo’: Permission denied
# find: ‘/proc/17/task/17/ns’: Permission denied
# find: ‘/proc/17/fd’: Permission denied
# find: ‘/proc/17/map_files’: Permission denied
# find: ‘/proc/17/fdinfo’: Permission denied
# find: ‘/proc/17/ns’: Permission denied
# find: ‘/proc/18/task/18/fd’: Permission denied
# find: ‘/proc/18/task/18/fdinfo’: Permission denied
# find: ‘/proc/18/task/18/ns’: Permission denied
# find: ‘/proc/18/fd’: Permission denied
# find: ‘/proc/18/map_files’: Permission denied
# find: ‘/proc/18/fdinfo’: Permission denied
# find: ‘/proc/18/ns’: Permission denied
# find: ‘/proc/20/task/20/fd’: Permission denied
# find: ‘/proc/20/task/20/fdinfo’: Permission denied
# find: ‘/proc/20/task/20/ns’: Permission denied
# find: ‘/proc/20/fd’: Permission denied
# find: ‘/proc/20/map_files’: Permission denied
# find: ‘/proc/20/fdinfo’: Permission denied
# find: ‘/proc/20/ns’: Permission denied
# find: ‘/proc/21/task/21/fd’: Permission denied
# find: ‘/proc/21/task/21/fdinfo’: Permission denied
# find: ‘/proc/21/task/21/ns’: Permission denied
# find: ‘/proc/21/fd’: Permission denied
# find: ‘/proc/21/map_files’: Permission denied
# find: ‘/proc/21/fdinfo’: Permission denied
# find: ‘/proc/21/ns’: Permission denied
# find: ‘/proc/22/task/22/fd’: Permission denied
# find: ‘/proc/22/task/22/fdinfo’: Permission denied
# find: ‘/proc/22/task/22/ns’: Permission denied
# find: ‘/proc/22/fd’: Permission denied
# find: ‘/proc/22/map_files’: Permission denied
# find: ‘/proc/22/fdinfo’: Permission denied
# find: ‘/proc/22/ns’: Permission denied
# find: ‘/proc/23/task/23/fd’: Permission denied
# find: ‘/proc/23/task/23/fdinfo’: Permission denied
# find: ‘/proc/23/task/23/ns’: Permission denied
# find: ‘/proc/23/fd’: Permission denied
# find: ‘/proc/23/map_files’: Permission denied
# find: ‘/proc/23/fdinfo’: Permission denied
# find: ‘/proc/23/ns’: Permission denied
# find: ‘/proc/24/task/24/fd’: Permission denied
# find: ‘/proc/24/task/24/fdinfo’: Permission denied
# find: ‘/proc/24/task/24/ns’: Permission denied
# find: ‘/proc/24/fd’: Permission denied
# find: ‘/proc/24/map_files’: Permission denied
# find: ‘/proc/24/fdinfo’: Permission denied
# find: ‘/proc/24/ns’: Permission denied
# find: ‘/proc/26/task/26/fd’: Permission denied
# find: ‘/proc/26/task/26/fdinfo’: Permission denied
# find: ‘/proc/26/task/26/ns’: Permission denied
# find: ‘/proc/26/fd’: Permission denied
# find: ‘/proc/26/map_files’: Permission denied
# find: ‘/proc/26/fdinfo’: Permission denied
# find: ‘/proc/26/ns’: Permission denied
# find: ‘/proc/27/task/27/fd’: Permission denied
# find: ‘/proc/27/task/27/fdinfo’: Permission denied
# find: ‘/proc/27/task/27/ns’: Permission denied
# find: ‘/proc/27/fd’: Permission denied
# find: ‘/proc/27/map_files’: Permission denied
# find: ‘/proc/27/fdinfo’: Permission denied
# find: ‘/proc/27/ns’: Permission denied
# find: ‘/proc/28/task/28/fd’: Permission denied
# find: ‘/proc/28/task/28/fdinfo’: Permission denied
# find: ‘/proc/28/task/28/ns’: Permission denied
# find: ‘/proc/28/fd’: Permission denied
# find: ‘/proc/28/map_files’: Permission denied
# find: ‘/proc/28/fdinfo’: Permission denied
# find: ‘/proc/28/ns’: Permission denied
# find: ‘/proc/29/task/29/fd’: Permission denied
# find: ‘/proc/29/task/29/fdinfo’: Permission denied
# find: ‘/proc/29/task/29/ns’: Permission denied
# find: ‘/proc/29/fd’: Permission denied
# find: ‘/proc/29/map_files’: Permission denied
# find: ‘/proc/29/fdinfo’: Permission denied
# find: ‘/proc/29/ns’: Permission denied
# find: ‘/proc/30/task/30/fd’: Permission denied
# find: ‘/proc/30/task/30/fdinfo’: Permission denied
# find: ‘/proc/30/task/30/ns’: Permission denied
# find: ‘/proc/30/fd’: Permission denied
# find: ‘/proc/30/map_files’: Permission denied
# find: ‘/proc/30/fdinfo’: Permission denied
# find: ‘/proc/30/ns’: Permission denied
# find: ‘/proc/32/task/32/fd’: Permission denied
# find: ‘/proc/32/task/32/fdinfo’: Permission denied
# find: ‘/proc/32/task/32/ns’: Permission denied
# find: ‘/proc/32/fd’: Permission denied
# find: ‘/proc/32/map_files’: Permission denied
# find: ‘/proc/32/fdinfo’: Permission denied
# find: ‘/proc/32/ns’: Permission denied
# find: ‘/proc/33/task/33/fd’: Permission denied
# find: ‘/proc/33/task/33/fdinfo’: Permission denied
# find: ‘/proc/33/task/33/ns’: Permission denied
# find: ‘/proc/33/fd’: Permission denied
# find: ‘/proc/33/map_files’: Permission denied
# find: ‘/proc/33/fdinfo’: Permission denied
# find: ‘/proc/33/ns’: Permission denied
# find: ‘/proc/34/task/34/fd’: Permission denied
# find: ‘/proc/34/task/34/fdinfo’: Permission denied
# find: ‘/proc/34/task/34/ns’: Permission denied
# find: ‘/proc/34/fd’: Permission denied
# find: ‘/proc/34/map_files’: Permission denied
# find: ‘/proc/34/fdinfo’: Permission denied
# find: ‘/proc/34/ns’: Permission denied
# find: ‘/proc/35/task/35/fd’: Permission denied
# find: ‘/proc/35/task/35/fdinfo’: Permission denied
# find: ‘/proc/35/task/35/ns’: Permission denied
# find: ‘/proc/35/fd’: Permission denied
# find: ‘/proc/35/map_files’: Permission denied
# find: ‘/proc/35/fdinfo’: Permission denied
# find: ‘/proc/35/ns’: Permission denied
# find: ‘/proc/36/task/36/fd’: Permission denied
# find: ‘/proc/36/task/36/fdinfo’: Permission denied
# find: ‘/proc/36/task/36/ns’: Permission denied
# find: ‘/proc/36/fd’: Permission denied
# find: ‘/proc/36/map_files’: Permission denied
# find: ‘/proc/36/fdinfo’: Permission denied
# find: ‘/proc/36/ns’: Permission denied
# find: ‘/proc/38/task/38/fd’: Permission denied
# find: ‘/proc/38/task/38/fdinfo’: Permission denied
# find: ‘/proc/38/task/38/ns’: Permission denied
# find: ‘/proc/38/fd’: Permission denied
# find: ‘/proc/38/map_files’: Permission denied
# find: ‘/proc/38/fdinfo’: Permission denied
# find: ‘/proc/38/ns’: Permission denied
# find: ‘/proc/39/task/39/fd’: Permission denied
# find: ‘/proc/39/task/39/fdinfo’: Permission denied
# find: ‘/proc/39/task/39/ns’: Permission denied
# find: ‘/proc/39/fd’: Permission denied
# find: ‘/proc/39/map_files’: Permission denied
# find: ‘/proc/39/fdinfo’: Permission denied
# find: ‘/proc/39/ns’: Permission denied
# find: ‘/proc/40/task/40/fd’: Permission denied
# find: ‘/proc/40/task/40/fdinfo’: Permission denied
# find: ‘/proc/40/task/40/ns’: Permission denied
# find: ‘/proc/40/fd’: Permission denied
# find: ‘/proc/40/map_files’: Permission denied
# find: ‘/proc/40/fdinfo’: Permission denied
# find: ‘/proc/40/ns’: Permission denied
# find: ‘/proc/41/task/41/fd’: Permission denied
# find: ‘/proc/41/task/41/fdinfo’: Permission denied
# find: ‘/proc/41/task/41/ns’: Permission denied
# find: ‘/proc/41/fd’: Permission denied
# find: ‘/proc/41/map_files’: Permission denied
# find: ‘/proc/41/fdinfo’: Permission denied
# find: ‘/proc/41/ns’: Permission denied
# find: ‘/proc/42/task/42/fd’: Permission denied
# find: ‘/proc/42/task/42/fdinfo’: Permission denied
# find: ‘/proc/42/task/42/ns’: Permission denied
# find: ‘/proc/42/fd’: Permission denied
# find: ‘/proc/42/map_files’: Permission denied
# find: ‘/proc/42/fdinfo’: Permission denied
# find: ‘/proc/42/ns’: Permission denied
# find: ‘/proc/44/task/44/fd’: Permission denied
# find: ‘/proc/44/task/44/fdinfo’: Permission denied
# find: ‘/proc/44/task/44/ns’: Permission denied
# find: ‘/proc/44/fd’: Permission denied
# find: ‘/proc/44/map_files’: Permission denied
# find: ‘/proc/44/fdinfo’: Permission denied
# find: ‘/proc/44/ns’: Permission denied
# find: ‘/proc/45/task/45/fd’: Permission denied
# find: ‘/proc/45/task/45/fdinfo’: Permission denied
# find: ‘/proc/45/task/45/ns’: Permission denied
# find: ‘/proc/45/fd’: Permission denied
# find: ‘/proc/45/map_files’: Permission denied
# find: ‘/proc/45/fdinfo’: Permission denied
# find: ‘/proc/45/ns’: Permission denied
# find: ‘/proc/46/task/46/fd’: Permission denied
# find: ‘/proc/46/task/46/fdinfo’: Permission denied
# find: ‘/proc/46/task/46/ns’: Permission denied
# find: ‘/proc/46/fd’: Permission denied
# find: ‘/proc/46/map_files’: Permission denied
# find: ‘/proc/46/fdinfo’: Permission denied
# find: ‘/proc/46/ns’: Permission denied
# find: ‘/proc/47/task/47/fd’: Permission denied
# find: ‘/proc/47/task/47/fdinfo’: Permission denied
# find: ‘/proc/47/task/47/ns’: Permission denied
# find: ‘/proc/47/fd’: Permission denied
# find: ‘/proc/47/map_files’: Permission denied
# find: ‘/proc/47/fdinfo’: Permission denied
# find: ‘/proc/47/ns’: Permission denied
# find: ‘/proc/48/task/48/fd’: Permission denied
# find: ‘/proc/48/task/48/fdinfo’: Permission denied
# find: ‘/proc/48/task/48/ns’: Permission denied
# find: ‘/proc/48/fd’: Permission denied
# find: ‘/proc/48/map_files’: Permission denied
# find: ‘/proc/48/fdinfo’: Permission denied
# find: ‘/proc/48/ns’: Permission denied
# find: ‘/proc/50/task/50/fd’: Permission denied
# find: ‘/proc/50/task/50/fdinfo’: Permission denied
# find: ‘/proc/50/task/50/ns’: Permission denied
# find: ‘/proc/50/fd’: Permission denied
# find: ‘/proc/50/map_files’: Permission denied
# find: ‘/proc/50/fdinfo’: Permission denied
# find: ‘/proc/50/ns’: Permission denied
# find: ‘/proc/51/task/51/fd’: Permission denied
# find: ‘/proc/51/task/51/fdinfo’: Permission denied
# find: ‘/proc/51/task/51/ns’: Permission denied
# find: ‘/proc/51/fd’: Permission denied
# find: ‘/proc/51/map_files’: Permission denied
# find: ‘/proc/51/fdinfo’: Permission denied
# find: ‘/proc/51/ns’: Permission denied
# find: ‘/proc/52/task/52/fd’: Permission denied
# find: ‘/proc/52/task/52/fdinfo’: Permission denied
# find: ‘/proc/52/task/52/ns’: Permission denied
# find: ‘/proc/52/fd’: Permission denied
# find: ‘/proc/52/map_files’: Permission denied
# find: ‘/proc/52/fdinfo’: Permission denied
# find: ‘/proc/52/ns’: Permission denied
# find: ‘/proc/53/task/53/fd’: Permission denied
# find: ‘/proc/53/task/53/fdinfo’: Permission denied
# find: ‘/proc/53/task/53/ns’: Permission denied
# find: ‘/proc/53/fd’: Permission denied
# find: ‘/proc/53/map_files’: Permission denied
# find: ‘/proc/53/fdinfo’: Permission denied
# find: ‘/proc/53/ns’: Permission denied
# find: ‘/proc/54/task/54/fd’: Permission denied
# find: ‘/proc/54/task/54/fdinfo’: Permission denied
# find: ‘/proc/54/task/54/ns’: Permission denied
# find: ‘/proc/54/fd’: Permission denied
# find: ‘/proc/54/map_files’: Permission denied
# find: ‘/proc/54/fdinfo’: Permission denied
# find: ‘/proc/54/ns’: Permission denied
# find: ‘/proc/56/task/56/fd’: Permission denied
# find: ‘/proc/56/task/56/fdinfo’: Permission denied
# find: ‘/proc/56/task/56/ns’: Permission denied
# find: ‘/proc/56/fd’: Permission denied
# find: ‘/proc/56/map_files’: Permission denied
# find: ‘/proc/56/fdinfo’: Permission denied
# find: ‘/proc/56/ns’: Permission denied
# find: ‘/proc/57/task/57/fd’: Permission denied
# find: ‘/proc/57/task/57/fdinfo’: Permission denied
# find: ‘/proc/57/task/57/ns’: Permission denied
# find: ‘/proc/57/fd’: Permission denied
# find: ‘/proc/57/map_files’: Permission denied
# find: ‘/proc/57/fdinfo’: Permission denied
# find: ‘/proc/57/ns’: Permission denied
# find: ‘/proc/58/task/58/fd’: Permission denied
# find: ‘/proc/58/task/58/fdinfo’: Permission denied
# find: ‘/proc/58/task/58/ns’: Permission denied
# find: ‘/proc/58/fd’: Permission denied
# find: ‘/proc/58/map_files’: Permission denied
# find: ‘/proc/58/fdinfo’: Permission denied
# find: ‘/proc/58/ns’: Permission denied
# find: ‘/proc/59/task/59/fd’: Permission denied
# find: ‘/proc/59/task/59/fdinfo’: Permission denied
# find: ‘/proc/59/task/59/ns’: Permission denied
# find: ‘/proc/59/fd’: Permission denied
# find: ‘/proc/59/map_files’: Permission denied
# find: ‘/proc/59/fdinfo’: Permission denied
# find: ‘/proc/59/ns’: Permission denied
# find: ‘/proc/60/task/60/fd’: Permission denied
# find: ‘/proc/60/task/60/fdinfo’: Permission denied
# find: ‘/proc/60/task/60/ns’: Permission denied
# find: ‘/proc/60/fd’: Permission denied
# find: ‘/proc/60/map_files’: Permission denied
# find: ‘/proc/60/fdinfo’: Permission denied
# find: ‘/proc/60/ns’: Permission denied
# find: ‘/proc/63/task/63/fd’: Permission denied
# find: ‘/proc/63/task/63/fdinfo’: Permission denied
# find: ‘/proc/63/task/63/ns’: Permission denied
# find: ‘/proc/63/fd’: Permission denied
# find: ‘/proc/63/map_files’: Permission denied
# find: ‘/proc/63/fdinfo’: Permission denied
# find: ‘/proc/63/ns’: Permission denied
# find: ‘/proc/64/task/64/fd’: Permission denied
# find: ‘/proc/64/task/64/fdinfo’: Permission denied
# find: ‘/proc/64/task/64/ns’: Permission denied
# find: ‘/proc/64/fd’: Permission denied
# find: ‘/proc/64/map_files’: Permission denied
# find: ‘/proc/64/fdinfo’: Permission denied
# find: ‘/proc/64/ns’: Permission denied
# find: ‘/proc/65/task/65/fd’: Permission denied
# find: ‘/proc/65/task/65/fdinfo’: Permission denied
# find: ‘/proc/65/task/65/ns’: Permission denied
# find: ‘/proc/65/fd’: Permission denied
# find: ‘/proc/65/map_files’: Permission denied
# find: ‘/proc/65/fdinfo’: Permission denied
# find: ‘/proc/65/ns’: Permission denied
# find: ‘/proc/66/task/66/fd’: Permission denied
# find: ‘/proc/66/task/66/fdinfo’: Permission denied
# find: ‘/proc/66/task/66/ns’: Permission denied
# find: ‘/proc/66/fd’: Permission denied
# find: ‘/proc/66/map_files’: Permission denied
# find: ‘/proc/66/fdinfo’: Permission denied
# find: ‘/proc/66/ns’: Permission denied
# find: ‘/proc/67/task/67/fd’: Permission denied
# find: ‘/proc/67/task/67/fdinfo’: Permission denied
# find: ‘/proc/67/task/67/ns’: Permission denied
# find: ‘/proc/67/fd’: Permission denied
# find: ‘/proc/67/map_files’: Permission denied
# find: ‘/proc/67/fdinfo’: Permission denied
# find: ‘/proc/67/ns’: Permission denied
# find: ‘/proc/68/task/68/fd’: Permission denied
# find: ‘/proc/68/task/68/fdinfo’: Permission denied
# find: ‘/proc/68/task/68/ns’: Permission denied
# find: ‘/proc/68/fd’: Permission denied
# find: ‘/proc/68/map_files’: Permission denied
# find: ‘/proc/68/fdinfo’: Permission denied
# find: ‘/proc/68/ns’: Permission denied
# find: ‘/proc/114/task/114/fd’: Permission denied
# find: ‘/proc/114/task/114/fdinfo’: Permission denied
# find: ‘/proc/114/task/114/ns’: Permission denied
# find: ‘/proc/114/fd’: Permission denied
# find: ‘/proc/114/map_files’: Permission denied
# find: ‘/proc/114/fdinfo’: Permission denied
# find: ‘/proc/114/ns’: Permission denied
# find: ‘/proc/115/task/115/fd’: Permission denied
# find: ‘/proc/115/task/115/fdinfo’: Permission denied
# find: ‘/proc/115/task/115/ns’: Permission denied
# find: ‘/proc/115/fd’: Permission denied
# find: ‘/proc/115/map_files’: Permission denied
# find: ‘/proc/115/fdinfo’: Permission denied
# find: ‘/proc/115/ns’: Permission denied
# find: ‘/proc/116/task/116/fd’: Permission denied
# find: ‘/proc/116/task/116/fdinfo’: Permission denied
# find: ‘/proc/116/task/116/ns’: Permission denied
# find: ‘/proc/116/fd’: Permission denied
# find: ‘/proc/116/map_files’: Permission denied
# find: ‘/proc/116/fdinfo’: Permission denied
# find: ‘/proc/116/ns’: Permission denied
# find: ‘/proc/117/task/117/fd’: Permission denied
# find: ‘/proc/117/task/117/fdinfo’: Permission denied
# find: ‘/proc/117/task/117/ns’: Permission denied
# find: ‘/proc/117/fd’: Permission denied
# find: ‘/proc/117/map_files’: Permission denied
# find: ‘/proc/117/fdinfo’: Permission denied
# find: ‘/proc/117/ns’: Permission denied
# find: ‘/proc/118/task/118/fd’: Permission denied
# find: ‘/proc/118/task/118/fdinfo’: Permission denied
# find: ‘/proc/118/task/118/ns’: Permission denied
# find: ‘/proc/118/fd’: Permission denied
# find: ‘/proc/118/map_files’: Permission denied
# find: ‘/proc/118/fdinfo’: Permission denied
# find: ‘/proc/118/ns’: Permission denied
# find: ‘/proc/119/task/119/fd’: Permission denied
# find: ‘/proc/119/task/119/fdinfo’: Permission denied
# find: ‘/proc/119/task/119/ns’: Permission denied
# find: ‘/proc/119/fd’: Permission denied
# find: ‘/proc/119/map_files’: Permission denied
# find: ‘/proc/119/fdinfo’: Permission denied
# find: ‘/proc/119/ns’: Permission denied
# find: ‘/proc/120/task/120/fd’: Permission denied
# find: ‘/proc/120/task/120/fdinfo’: Permission denied
# find: ‘/proc/120/task/120/ns’: Permission denied
# find: ‘/proc/120/fd’: Permission denied
# find: ‘/proc/120/map_files’: Permission denied
# find: ‘/proc/120/fdinfo’: Permission denied
# find: ‘/proc/120/ns’: Permission denied
# find: ‘/proc/121/task/121/fd’: Permission denied
# find: ‘/proc/121/task/121/fdinfo’: Permission denied
# find: ‘/proc/121/task/121/ns’: Permission denied
# find: ‘/proc/121/fd’: Permission denied
# find: ‘/proc/121/map_files’: Permission denied
# find: ‘/proc/121/fdinfo’: Permission denied
# find: ‘/proc/121/ns’: Permission denied
# find: ‘/proc/123/task/123/fd’: Permission denied
# find: ‘/proc/123/task/123/fdinfo’: Permission denied
# find: ‘/proc/123/task/123/ns’: Permission denied
# find: ‘/proc/123/fd’: Permission denied
# find: ‘/proc/123/map_files’: Permission denied
# find: ‘/proc/123/fdinfo’: Permission denied
# find: ‘/proc/123/ns’: Permission denied
# find: ‘/proc/126/task/126/fd’: Permission denied
# find: ‘/proc/126/task/126/fdinfo’: Permission denied
# find: ‘/proc/126/task/126/ns’: Permission denied
# find: ‘/proc/126/fd’: Permission denied
# find: ‘/proc/126/map_files’: Permission denied
# find: ‘/proc/126/fdinfo’: Permission denied
# find: ‘/proc/126/ns’: Permission denied
# find: ‘/proc/127/task/127/fd’: Permission denied
# find: ‘/proc/127/task/127/fdinfo’: Permission denied
# find: ‘/proc/127/task/127/ns’: Permission denied
# find: ‘/proc/127/fd’: Permission denied
# find: ‘/proc/127/map_files’: Permission denied
# find: ‘/proc/127/fdinfo’: Permission denied
# find: ‘/proc/127/ns’: Permission denied
# find: ‘/proc/129/task/129/fd’: Permission denied
# find: ‘/proc/129/task/129/fdinfo’: Permission denied
# find: ‘/proc/129/task/129/ns’: Permission denied
# find: ‘/proc/129/fd’: Permission denied
# find: ‘/proc/129/map_files’: Permission denied
# find: ‘/proc/129/fdinfo’: Permission denied
# find: ‘/proc/129/ns’: Permission denied
# find: ‘/proc/130/task/130/fd’: Permission denied
# find: ‘/proc/130/task/130/fdinfo’: Permission denied
# find: ‘/proc/130/task/130/ns’: Permission denied
# find: ‘/proc/130/fd’: Permission denied
# find: ‘/proc/130/map_files’: Permission denied
# find: ‘/proc/130/fdinfo’: Permission denied
# find: ‘/proc/130/ns’: Permission denied
# find: ‘/proc/131/task/131/fd’: Permission denied
# find: ‘/proc/131/task/131/fdinfo’: Permission denied
# find: ‘/proc/131/task/131/ns’: Permission denied
# find: ‘/proc/131/fd’: Permission denied
# find: ‘/proc/131/map_files’: Permission denied
# find: ‘/proc/131/fdinfo’: Permission denied
# find: ‘/proc/131/ns’: Permission denied
# find: ‘/proc/133/task/133/fd’: Permission denied
# find: ‘/proc/133/task/133/fdinfo’: Permission denied
# find: ‘/proc/133/task/133/ns’: Permission denied
# find: ‘/proc/133/fd’: Permission denied
# find: ‘/proc/133/map_files’: Permission denied
# find: ‘/proc/133/fdinfo’: Permission denied
# find: ‘/proc/133/ns’: Permission denied
# find: ‘/proc/143/task/143/fd’: Permission denied
# find: ‘/proc/143/task/143/fdinfo’: Permission denied
# find: ‘/proc/143/task/143/ns’: Permission denied
# find: ‘/proc/143/fd’: Permission denied
# find: ‘/proc/143/map_files’: Permission denied
# find: ‘/proc/143/fdinfo’: Permission denied
# find: ‘/proc/143/ns’: Permission denied
# find: ‘/proc/146/task/146/fd’: Permission denied
# find: ‘/proc/146/task/146/fdinfo’: Permission denied
# find: ‘/proc/146/task/146/ns’: Permission denied
# find: ‘/proc/146/fd’: Permission denied
# find: ‘/proc/146/map_files’: Permission denied
# find: ‘/proc/146/fdinfo’: Permission denied
# find: ‘/proc/146/ns’: Permission denied
# find: ‘/proc/161/task/161/fd’: Permission denied
# find: ‘/proc/161/task/161/fdinfo’: Permission denied
# find: ‘/proc/161/task/161/ns’: Permission denied
# find: ‘/proc/161/fd’: Permission denied
# find: ‘/proc/161/map_files’: Permission denied
# find: ‘/proc/161/fdinfo’: Permission denied
# find: ‘/proc/161/ns’: Permission denied
# find: ‘/proc/229/task/229/fd’: Permission denied
# find: ‘/proc/229/task/229/fdinfo’: Permission denied
# find: ‘/proc/229/task/229/ns’: Permission denied
# find: ‘/proc/229/fd’: Permission denied
# find: ‘/proc/229/map_files’: Permission denied
# find: ‘/proc/229/fdinfo’: Permission denied
# find: ‘/proc/229/ns’: Permission denied
# find: ‘/proc/230/task/230/fd’: Permission denied
# find: ‘/proc/230/task/230/fdinfo’: Permission denied
# find: ‘/proc/230/task/230/ns’: Permission denied
# find: ‘/proc/230/fd’: Permission denied
# find: ‘/proc/230/map_files’: Permission denied
# find: ‘/proc/230/fdinfo’: Permission denied
# find: ‘/proc/230/ns’: Permission denied
# find: ‘/proc/231/task/231/fd’: Permission denied
# find: ‘/proc/231/task/231/fdinfo’: Permission denied
# find: ‘/proc/231/task/231/ns’: Permission denied
# find: ‘/proc/231/fd’: Permission denied
# find: ‘/proc/231/map_files’: Permission denied
# find: ‘/proc/231/fdinfo’: Permission denied
# find: ‘/proc/231/ns’: Permission denied
# find: ‘/proc/232/task/232/fd’: Permission denied
# find: ‘/proc/232/task/232/fdinfo’: Permission denied
# find: ‘/proc/232/task/232/ns’: Permission denied
# find: ‘/proc/232/fd’: Permission denied
# find: ‘/proc/232/map_files’: Permission denied
# find: ‘/proc/232/fdinfo’: Permission denied
# find: ‘/proc/232/ns’: Permission denied
# find: ‘/proc/233/task/233/fd’: Permission denied
# find: ‘/proc/233/task/233/fdinfo’: Permission denied
# find: ‘/proc/233/task/233/ns’: Permission denied
# find: ‘/proc/233/fd’: Permission denied
# find: ‘/proc/233/map_files’: Permission denied
# find: ‘/proc/233/fdinfo’: Permission denied
# find: ‘/proc/233/ns’: Permission denied
# find: ‘/proc/234/task/234/fd’: Permission denied
# find: ‘/proc/234/task/234/fdinfo’: Permission denied
# find: ‘/proc/234/task/234/ns’: Permission denied
# find: ‘/proc/234/fd’: Permission denied
# find: ‘/proc/234/map_files’: Permission denied
# find: ‘/proc/234/fdinfo’: Permission denied
# find: ‘/proc/234/ns’: Permission denied
# find: ‘/proc/235/task/235/fd’: Permission denied
# find: ‘/proc/235/task/235/fdinfo’: Permission denied
# find: ‘/proc/235/task/235/ns’: Permission denied
# find: ‘/proc/235/fd’: Permission denied
# find: ‘/proc/235/map_files’: Permission denied
# find: ‘/proc/235/fdinfo’: Permission denied
# find: ‘/proc/235/ns’: Permission denied
# find: ‘/proc/236/task/236/fd’: Permission denied
# find: ‘/proc/236/task/236/fdinfo’: Permission denied
# find: ‘/proc/236/task/236/ns’: Permission denied
# find: ‘/proc/236/fd’: Permission denied
# find: ‘/proc/236/map_files’: Permission denied
# find: ‘/proc/236/fdinfo’: Permission denied
# find: ‘/proc/236/ns’: Permission denied
# find: ‘/proc/237/task/237/fd’: Permission denied
# find: ‘/proc/237/task/237/fdinfo’: Permission denied
# find: ‘/proc/237/task/237/ns’: Permission denied
# find: ‘/proc/237/fd’: Permission denied
# find: ‘/proc/237/map_files’: Permission denied
# find: ‘/proc/237/fdinfo’: Permission denied
# find: ‘/proc/237/ns’: Permission denied
# find: ‘/proc/238/task/238/fd’: Permission denied
# find: ‘/proc/238/task/238/fdinfo’: Permission denied
# find: ‘/proc/238/task/238/ns’: Permission denied
# find: ‘/proc/238/fd’: Permission denied
# find: ‘/proc/238/map_files’: Permission denied
# find: ‘/proc/238/fdinfo’: Permission denied
# find: ‘/proc/238/ns’: Permission denied
# find: ‘/proc/239/task/239/fd’: Permission denied
# find: ‘/proc/239/task/239/fdinfo’: Permission denied
# find: ‘/proc/239/task/239/ns’: Permission denied
# find: ‘/proc/239/fd’: Permission denied
# find: ‘/proc/239/map_files’: Permission denied
# find: ‘/proc/239/fdinfo’: Permission denied
# find: ‘/proc/239/ns’: Permission denied
# find: ‘/proc/240/task/240/fd’: Permission denied
# find: ‘/proc/240/task/240/fdinfo’: Permission denied
# find: ‘/proc/240/task/240/ns’: Permission denied
# find: ‘/proc/240/fd’: Permission denied
# find: ‘/proc/240/map_files’: Permission denied
# find: ‘/proc/240/fdinfo’: Permission denied
# find: ‘/proc/240/ns’: Permission denied
# find: ‘/proc/245/task/245/fd’: Permission denied
# find: ‘/proc/245/task/245/fdinfo’: Permission denied
# find: ‘/proc/245/task/245/ns’: Permission denied
# find: ‘/proc/245/fd’: Permission denied
# find: ‘/proc/245/map_files’: Permission denied
# find: ‘/proc/245/fdinfo’: Permission denied
# find: ‘/proc/245/ns’: Permission denied
# find: ‘/proc/246/task/246/fd’: Permission denied
# find: ‘/proc/246/task/246/fdinfo’: Permission denied
# find: ‘/proc/246/task/246/ns’: Permission denied
# find: ‘/proc/246/fd’: Permission denied
# find: ‘/proc/246/map_files’: Permission denied
# find: ‘/proc/246/fdinfo’: Permission denied
# find: ‘/proc/246/ns’: Permission denied
# find: ‘/proc/272/task/272/fd’: Permission denied
# find: ‘/proc/272/task/272/fdinfo’: Permission denied
# find: ‘/proc/272/task/272/ns’: Permission denied
# find: ‘/proc/272/fd’: Permission denied
# find: ‘/proc/272/map_files’: Permission denied
# find: ‘/proc/272/fdinfo’: Permission denied
# find: ‘/proc/272/ns’: Permission denied
# find: ‘/proc/273/task/273/fd’: Permission denied
# find: ‘/proc/273/task/273/fdinfo’: Permission denied
# find: ‘/proc/273/task/273/ns’: Permission denied
# find: ‘/proc/273/fd’: Permission denied
# find: ‘/proc/273/map_files’: Permission denied
# find: ‘/proc/273/fdinfo’: Permission denied
# find: ‘/proc/273/ns’: Permission denied
# find: ‘/proc/274/task/274/fd’: Permission denied
# find: ‘/proc/274/task/274/fdinfo’: Permission denied
# find: ‘/proc/274/task/274/ns’: Permission denied
# find: ‘/proc/274/fd’: Permission denied
# find: ‘/proc/274/map_files’: Permission denied
# find: ‘/proc/274/fdinfo’: Permission denied
# find: ‘/proc/274/ns’: Permission denied
# find: ‘/proc/284/task/284/fd’: Permission denied
# find: ‘/proc/284/task/284/fdinfo’: Permission denied
# find: ‘/proc/284/task/284/ns’: Permission denied
# find: ‘/proc/284/fd’: Permission denied
# find: ‘/proc/284/map_files’: Permission denied
# find: ‘/proc/284/fdinfo’: Permission denied
# find: ‘/proc/284/ns’: Permission denied
# find: ‘/proc/289/task/289/fd’: Permission denied
# find: ‘/proc/289/task/289/fdinfo’: Permission denied
# find: ‘/proc/289/task/289/ns’: Permission denied
# find: ‘/proc/289/fd’: Permission denied
# find: ‘/proc/289/map_files’: Permission denied
# find: ‘/proc/289/fdinfo’: Permission denied
# find: ‘/proc/289/ns’: Permission denied
# find: ‘/proc/292/task/292/fd’: Permission denied
# find: ‘/proc/292/task/292/fdinfo’: Permission denied
# find: ‘/proc/292/task/292/ns’: Permission denied
# find: ‘/proc/292/fd’: Permission denied
# find: ‘/proc/292/map_files’: Permission denied
# find: ‘/proc/292/fdinfo’: Permission denied
# find: ‘/proc/292/ns’: Permission denied
# find: ‘/proc/307/task/307/fd’: Permission denied
# find: ‘/proc/307/task/307/fdinfo’: Permission denied
# find: ‘/proc/307/task/307/ns’: Permission denied
# find: ‘/proc/307/fd’: Permission denied
# find: ‘/proc/307/map_files’: Permission denied
# find: ‘/proc/307/fdinfo’: Permission denied
# find: ‘/proc/307/ns’: Permission denied
# find: ‘/proc/325/task/325/fd’: Permission denied
# find: ‘/proc/325/task/325/fdinfo’: Permission denied
# find: ‘/proc/325/task/325/ns’: Permission denied
# find: ‘/proc/325/fd’: Permission denied
# find: ‘/proc/325/map_files’: Permission denied
# find: ‘/proc/325/fdinfo’: Permission denied
# find: ‘/proc/325/ns’: Permission denied
# find: ‘/proc/330/task/330/fd’: Permission denied
# find: ‘/proc/330/task/330/fdinfo’: Permission denied
# find: ‘/proc/330/task/330/ns’: Permission denied
# find: ‘/proc/330/fd’: Permission denied
# find: ‘/proc/330/map_files’: Permission denied
# find: ‘/proc/330/fdinfo’: Permission denied
# find: ‘/proc/330/ns’: Permission denied
# find: ‘/proc/351/task/351/fd’: Permission denied
# find: ‘/proc/351/task/351/fdinfo’: Permission denied
# find: ‘/proc/351/task/351/ns’: Permission denied
# find: ‘/proc/351/fd’: Permission denied
# find: ‘/proc/351/map_files’: Permission denied
# find: ‘/proc/351/fdinfo’: Permission denied
# find: ‘/proc/351/ns’: Permission denied
# find: ‘/proc/366/task/366/fd’: Permission denied
# find: ‘/proc/366/task/366/fdinfo’: Permission denied
# find: ‘/proc/366/task/366/ns’: Permission denied
# find: ‘/proc/366/fd’: Permission denied
# find: ‘/proc/366/map_files’: Permission denied
# find: ‘/proc/366/fdinfo’: Permission denied
# find: ‘/proc/366/ns’: Permission denied
# find: ‘/proc/373/task/373/fd’: Permission denied
# find: ‘/proc/373/task/373/fdinfo’: Permission denied
# find: ‘/proc/373/task/373/ns’: Permission denied
# find: ‘/proc/373/fd’: Permission denied
# find: ‘/proc/373/map_files’: Permission denied
# find: ‘/proc/373/fdinfo’: Permission denied
# find: ‘/proc/373/ns’: Permission denied
# find: ‘/proc/377/task/377/fd’: Permission denied
# find: ‘/proc/377/task/377/fdinfo’: Permission denied
# find: ‘/proc/377/task/377/ns’: Permission denied
# find: ‘/proc/377/fd’: Permission denied
# find: ‘/proc/377/map_files’: Permission denied
# find: ‘/proc/377/fdinfo’: Permission denied
# find: ‘/proc/377/ns’: Permission denied
# find: ‘/proc/383/task/383/fd’: Permission denied
# find: ‘/proc/383/task/383/fdinfo’: Permission denied
# find: ‘/proc/383/task/383/ns’: Permission denied
# find: ‘/proc/383/fd’: Permission denied
# find: ‘/proc/383/map_files’: Permission denied
# find: ‘/proc/383/fdinfo’: Permission denied
# find: ‘/proc/383/ns’: Permission denied
# find: ‘/proc/385/task/385/fd’: Permission denied
# find: ‘/proc/385/task/385/fdinfo’: Permission denied
# find: ‘/proc/385/task/385/ns’: Permission denied
# find: ‘/proc/385/fd’: Permission denied
# find: ‘/proc/385/map_files’: Permission denied
# find: ‘/proc/385/fdinfo’: Permission denied
# find: ‘/proc/385/ns’: Permission denied
# find: ‘/proc/394/task/394/fd’: Permission denied
# find: ‘/proc/394/task/394/fdinfo’: Permission denied
# find: ‘/proc/394/task/394/ns’: Permission denied
# find: ‘/proc/394/fd’: Permission denied
# find: ‘/proc/394/map_files’: Permission denied
# find: ‘/proc/394/fdinfo’: Permission denied
# find: ‘/proc/394/ns’: Permission denied
# find: ‘/proc/400/task/400/fd’: Permission denied
# find: ‘/proc/400/task/400/fdinfo’: Permission denied
# find: ‘/proc/400/task/400/ns’: Permission denied
# find: ‘/proc/400/fd’: Permission denied
# find: ‘/proc/400/map_files’: Permission denied
# find: ‘/proc/400/fdinfo’: Permission denied
# find: ‘/proc/400/ns’: Permission denied
# find: ‘/proc/401/task/401/fd’: Permission denied
# find: ‘/proc/401/task/401/fdinfo’: Permission denied
# find: ‘/proc/401/task/401/ns’: Permission denied
# find: ‘/proc/401/fd’: Permission denied
# find: ‘/proc/401/map_files’: Permission denied
# find: ‘/proc/401/fdinfo’: Permission denied
# find: ‘/proc/401/ns’: Permission denied
# find: ‘/proc/439/task/439/fd’: Permission denied
# find: ‘/proc/439/task/439/fdinfo’: Permission denied
# find: ‘/proc/439/task/439/ns’: Permission denied
# find: ‘/proc/439/fd’: Permission denied
# find: ‘/proc/439/map_files’: Permission denied
# find: ‘/proc/439/fdinfo’: Permission denied
# find: ‘/proc/439/ns’: Permission denied
# find: ‘/proc/440/task/440/fd’: Permission denied
# find: ‘/proc/440/task/440/fdinfo’: Permission denied
# find: ‘/proc/440/task/440/ns’: Permission denied
# find: ‘/proc/440/fd’: Permission denied
# find: ‘/proc/440/map_files’: Permission denied
# find: ‘/proc/440/fdinfo’: Permission denied
# find: ‘/proc/440/ns’: Permission denied
# find: ‘/proc/446/task/446/fd’: Permission denied
# find: ‘/proc/446/task/446/fdinfo’: Permission denied
# find: ‘/proc/446/task/446/ns’: Permission denied
# find: ‘/proc/446/fd’: Permission denied
# find: ‘/proc/446/map_files’: Permission denied
# find: ‘/proc/446/fdinfo’: Permission denied
# find: ‘/proc/446/ns’: Permission denied
# find: ‘/proc/476/task/476/fd’: Permission denied
# find: ‘/proc/476/task/476/fdinfo’: Permission denied
# find: ‘/proc/476/task/476/ns’: Permission denied
# find: ‘/proc/476/fd’: Permission denied
# find: ‘/proc/476/map_files’: Permission denied
# find: ‘/proc/476/fdinfo’: Permission denied
# find: ‘/proc/476/ns’: Permission denied
# find: ‘/proc/486/task/486/fd’: Permission denied
# find: ‘/proc/486/task/486/fdinfo’: Permission denied
# find: ‘/proc/486/task/486/ns’: Permission denied
# find: ‘/proc/486/fd’: Permission denied
# find: ‘/proc/486/map_files’: Permission denied
# find: ‘/proc/486/fdinfo’: Permission denied
# find: ‘/proc/486/ns’: Permission denied
# find: ‘/proc/552/task/552/fd’: Permission denied
# find: ‘/proc/552/task/552/fdinfo’: Permission denied
# find: ‘/proc/552/task/552/ns’: Permission denied
# find: ‘/proc/552/fd’: Permission denied
# find: ‘/proc/552/map_files’: Permission denied
# find: ‘/proc/552/fdinfo’: Permission denied
# find: ‘/proc/552/ns’: Permission denied
# find: ‘/proc/557/task/557/fd’: Permission denied
# find: ‘/proc/557/task/557/fdinfo’: Permission denied
# find: ‘/proc/557/task/557/ns’: Permission denied
# find: ‘/proc/557/fd’: Permission denied
# find: ‘/proc/557/map_files’: Permission denied
# find: ‘/proc/557/fdinfo’: Permission denied
# find: ‘/proc/557/ns’: Permission denied
# find: ‘/proc/591/task/591/fd’: Permission denied
# find: ‘/proc/591/task/591/fdinfo’: Permission denied
# find: ‘/proc/591/task/591/ns’: Permission denied
# find: ‘/proc/591/fd’: Permission denied
# find: ‘/proc/591/map_files’: Permission denied
# find: ‘/proc/591/fdinfo’: Permission denied
# find: ‘/proc/591/ns’: Permission denied
# find: ‘/proc/612/task/612/fd’: Permission denied
# find: ‘/proc/612/task/612/fdinfo’: Permission denied
# find: ‘/proc/612/task/612/ns’: Permission denied
# find: ‘/proc/612/fd’: Permission denied
# find: ‘/proc/612/map_files’: Permission denied
# find: ‘/proc/612/fdinfo’: Permission denied
# find: ‘/proc/612/ns’: Permission denied
# find: ‘/proc/620/task/620/fd’: Permission denied
# find: ‘/proc/620/task/620/fdinfo’: Permission denied
# find: ‘/proc/620/task/620/ns’: Permission denied
# find: ‘/proc/620/fd’: Permission denied
# find: ‘/proc/620/map_files’: Permission denied
# find: ‘/proc/620/fdinfo’: Permission denied
# find: ‘/proc/620/ns’: Permission denied
# find: ‘/proc/625/task/625/fd’: Permission denied
# find: ‘/proc/625/task/625/fdinfo’: Permission denied
# find: ‘/proc/625/task/625/ns’: Permission denied
# find: ‘/proc/625/fd’: Permission denied
# find: ‘/proc/625/map_files’: Permission denied
# find: ‘/proc/625/fdinfo’: Permission denied
# find: ‘/proc/625/ns’: Permission denied
# find: ‘/proc/647/task/647/fd’: Permission denied
# find: ‘/proc/647/task/647/fdinfo’: Permission denied
# find: ‘/proc/647/task/647/ns’: Permission denied
# find: ‘/proc/647/fd’: Permission denied
# find: ‘/proc/647/map_files’: Permission denied
# find: ‘/proc/647/fdinfo’: Permission denied
# find: ‘/proc/647/ns’: Permission denied
# find: ‘/proc/660/task/660/fd’: Permission denied
# find: ‘/proc/660/task/660/fdinfo’: Permission denied
# find: ‘/proc/660/task/660/ns’: Permission denied
# find: ‘/proc/660/fd’: Permission denied
# find: ‘/proc/660/map_files’: Permission denied
# find: ‘/proc/660/fdinfo’: Permission denied
# find: ‘/proc/660/ns’: Permission denied
# find: ‘/proc/692/task/692/fd’: Permission denied
# find: ‘/proc/692/task/692/fdinfo’: Permission denied
# find: ‘/proc/692/task/692/ns’: Permission denied
# find: ‘/proc/692/fd’: Permission denied
# find: ‘/proc/692/map_files’: Permission denied
# find: ‘/proc/692/fdinfo’: Permission denied
# find: ‘/proc/692/ns’: Permission denied
# find: ‘/proc/828/task/828/fd’: Permission denied
# find: ‘/proc/828/task/828/fdinfo’: Permission denied
# find: ‘/proc/828/task/828/ns’: Permission denied
# find: ‘/proc/828/task/831/fd’: Permission denied
# find: ‘/proc/828/task/831/fdinfo’: Permission denied
# find: ‘/proc/828/task/831/ns’: Permission denied
# find: ‘/proc/828/fd’: Permission denied
# find: ‘/proc/828/map_files’: Permission denied
# find: ‘/proc/828/fdinfo’: Permission denied
# find: ‘/proc/828/ns’: Permission denied
# find: ‘/proc/830/task/830/fd’: Permission denied
# find: ‘/proc/830/task/830/fdinfo’: Permission denied
# find: ‘/proc/830/task/830/ns’: Permission denied
# find: ‘/proc/830/fd’: Permission denied
# find: ‘/proc/830/map_files’: Permission denied
# find: ‘/proc/830/fdinfo’: Permission denied
# find: ‘/proc/830/ns’: Permission denied
# find: ‘/proc/834/task/834/fd’: Permission denied
# find: ‘/proc/834/task/834/fdinfo’: Permission denied
# find: ‘/proc/834/task/834/ns’: Permission denied
# find: ‘/proc/834/task/876/fd’: Permission denied
# find: ‘/proc/834/task/876/fdinfo’: Permission denied
# find: ‘/proc/834/task/876/ns’: Permission denied
# find: ‘/proc/834/fd’: Permission denied
# find: ‘/proc/834/map_files’: Permission denied
# find: ‘/proc/834/fdinfo’: Permission denied
# find: ‘/proc/834/ns’: Permission denied
# find: ‘/proc/836/task/836/fd’: Permission denied
# find: ‘/proc/836/task/836/fdinfo’: Permission denied
# find: ‘/proc/836/task/836/ns’: Permission denied
# find: ‘/proc/836/fd’: Permission denied
# find: ‘/proc/836/map_files’: Permission denied
# find: ‘/proc/836/fdinfo’: Permission denied
# find: ‘/proc/836/ns’: Permission denied
# find: ‘/proc/840/task/840/fd’: Permission denied
# find: ‘/proc/840/task/840/fdinfo’: Permission denied
# find: ‘/proc/840/task/840/ns’: Permission denied
# find: ‘/proc/840/task/929/fd’: Permission denied
# find: ‘/proc/840/task/929/fdinfo’: Permission denied
# find: ‘/proc/840/task/929/ns’: Permission denied
# find: ‘/proc/840/task/994/fd’: Permission denied
# find: ‘/proc/840/task/994/fdinfo’: Permission denied
# find: ‘/proc/840/task/994/ns’: Permission denied
# find: ‘/proc/840/task/1087/fd’: Permission denied
# find: ‘/proc/840/task/1087/fdinfo’: Permission denied
# find: ‘/proc/840/task/1087/ns’: Permission denied
# find: ‘/proc/840/task/1158/fd’: Permission denied
# find: ‘/proc/840/task/1158/fdinfo’: Permission denied
# find: ‘/proc/840/task/1158/ns’: Permission denied
# find: ‘/proc/840/fd’: Permission denied
# find: ‘/proc/840/map_files’: Permission denied
# find: ‘/proc/840/fdinfo’: Permission denied
# find: ‘/proc/840/ns’: Permission denied
# find: ‘/proc/841/task/841/fd’: Permission denied
# find: ‘/proc/841/task/841/fdinfo’: Permission denied
# find: ‘/proc/841/task/841/ns’: Permission denied
# find: ‘/proc/841/task/1125/fd’: Permission denied
# find: ‘/proc/841/task/1125/fdinfo’: Permission denied
# find: ‘/proc/841/task/1125/ns’: Permission denied
# find: ‘/proc/841/fd’: Permission denied
# find: ‘/proc/841/map_files’: Permission denied
# find: ‘/proc/841/fdinfo’: Permission denied
# find: ‘/proc/841/ns’: Permission denied
# find: ‘/proc/842/task/842/fd’: Permission denied
# find: ‘/proc/842/task/842/fdinfo’: Permission denied
# find: ‘/proc/842/task/842/ns’: Permission denied
# find: ‘/proc/842/fd’: Permission denied
# find: ‘/proc/842/map_files’: Permission denied
# find: ‘/proc/842/fdinfo’: Permission denied
# find: ‘/proc/842/ns’: Permission denied
# find: ‘/proc/843/task/843/fd’: Permission denied
# find: ‘/proc/843/task/843/fdinfo’: Permission denied
# find: ‘/proc/843/task/843/ns’: Permission denied
# find: ‘/proc/843/task/905/fd’: Permission denied
# find: ‘/proc/843/task/905/fdinfo’: Permission denied
# find: ‘/proc/843/task/905/ns’: Permission denied
# find: ‘/proc/843/task/906/fd’: Permission denied
# find: ‘/proc/843/task/906/fdinfo’: Permission denied
# find: ‘/proc/843/task/906/ns’: Permission denied
# find: ‘/proc/843/task/907/fd’: Permission denied
# find: ‘/proc/843/task/907/fdinfo’: Permission denied
# find: ‘/proc/843/task/907/ns’: Permission denied
# find: ‘/proc/843/fd’: Permission denied
# find: ‘/proc/843/map_files’: Permission denied
# find: ‘/proc/843/fdinfo’: Permission denied
# find: ‘/proc/843/ns’: Permission denied
# find: ‘/proc/846/task/846/fd’: Permission denied
# find: ‘/proc/846/task/846/fdinfo’: Permission denied
# find: ‘/proc/846/task/846/ns’: Permission denied
# find: ‘/proc/846/task/862/fd’: Permission denied
# find: ‘/proc/846/task/862/fdinfo’: Permission denied
# find: ‘/proc/846/task/862/ns’: Permission denied
# find: ‘/proc/846/fd’: Permission denied
# find: ‘/proc/846/map_files’: Permission denied
# find: ‘/proc/846/fdinfo’: Permission denied
# find: ‘/proc/846/ns’: Permission denied
# find: ‘/proc/847/task/847/fd’: Permission denied
# find: ‘/proc/847/task/847/fdinfo’: Permission denied
# find: ‘/proc/847/task/847/ns’: Permission denied
# find: ‘/proc/847/task/1019/fd’: Permission denied
# find: ‘/proc/847/task/1019/fdinfo’: Permission denied
# find: ‘/proc/847/task/1019/ns’: Permission denied
# find: ‘/proc/847/task/1031/fd’: Permission denied
# find: ‘/proc/847/task/1031/fdinfo’: Permission denied
# find: ‘/proc/847/task/1031/ns’: Permission denied
# find: ‘/proc/847/fd’: Permission denied
# find: ‘/proc/847/map_files’: Permission denied
# find: ‘/proc/847/fdinfo’: Permission denied
# find: ‘/proc/847/ns’: Permission denied
# find: ‘/proc/849/task/849/fd’: Permission denied
# find: ‘/proc/849/task/849/fdinfo’: Permission denied
# find: ‘/proc/849/task/849/ns’: Permission denied
# find: ‘/proc/849/task/1139/fd’: Permission denied
# find: ‘/proc/849/task/1139/fdinfo’: Permission denied
# find: ‘/proc/849/task/1139/ns’: Permission denied
# find: ‘/proc/849/task/1166/fd’: Permission denied
# find: ‘/proc/849/task/1166/fdinfo’: Permission denied
# find: ‘/proc/849/task/1166/ns’: Permission denied
# find: ‘/proc/849/fd’: Permission denied
# find: ‘/proc/849/map_files’: Permission denied
# find: ‘/proc/849/fdinfo’: Permission denied
# find: ‘/proc/849/ns’: Permission denied
# find: ‘/proc/853/task/853/fd’: Permission denied
# find: ‘/proc/853/task/853/fdinfo’: Permission denied
# find: ‘/proc/853/task/853/ns’: Permission denied
# find: ‘/proc/853/fd’: Permission denied
# find: ‘/proc/853/map_files’: Permission denied
# find: ‘/proc/853/fdinfo’: Permission denied
# find: ‘/proc/853/ns’: Permission denied
# find: ‘/proc/854/task/854/fd’: Permission denied
# find: ‘/proc/854/task/854/fdinfo’: Permission denied
# find: ‘/proc/854/task/854/ns’: Permission denied
# find: ‘/proc/854/task/1091/fd’: Permission denied
# find: ‘/proc/854/task/1091/fdinfo’: Permission denied
# find: ‘/proc/854/task/1091/ns’: Permission denied
# find: ‘/proc/854/task/1094/fd’: Permission denied
# find: ‘/proc/854/task/1094/fdinfo’: Permission denied
# find: ‘/proc/854/task/1094/ns’: Permission denied
# find: ‘/proc/854/task/1095/fd’: Permission denied
# find: ‘/proc/854/task/1095/fdinfo’: Permission denied
# find: ‘/proc/854/task/1095/ns’: Permission denied
# find: ‘/proc/854/task/1181/fd’: Permission denied
# find: ‘/proc/854/task/1181/fdinfo’: Permission denied
# find: ‘/proc/854/task/1181/ns’: Permission denied
# find: ‘/proc/854/task/1201/fd’: Permission denied
# find: ‘/proc/854/task/1201/fdinfo’: Permission denied
# find: ‘/proc/854/task/1201/ns’: Permission denied
# find: ‘/proc/854/task/1202/fd’: Permission denied
# find: ‘/proc/854/task/1202/fdinfo’: Permission denied
# find: ‘/proc/854/task/1202/ns’: Permission denied
# find: ‘/proc/854/task/1294/fd’: Permission denied
# find: ‘/proc/854/task/1294/fdinfo’: Permission denied
# find: ‘/proc/854/task/1294/ns’: Permission denied
# find: ‘/proc/854/task/1295/fd’: Permission denied
# find: ‘/proc/854/task/1295/fdinfo’: Permission denied
# find: ‘/proc/854/task/1295/ns’: Permission denied
# find: ‘/proc/854/task/1296/fd’: Permission denied
# find: ‘/proc/854/task/1296/fdinfo’: Permission denied
# find: ‘/proc/854/task/1296/ns’: Permission denied
# find: ‘/proc/854/task/1297/fd’: Permission denied
# find: ‘/proc/854/task/1297/fdinfo’: Permission denied
# find: ‘/proc/854/task/1297/ns’: Permission denied
# find: ‘/proc/854/task/1301/fd’: Permission denied
# find: ‘/proc/854/task/1301/fdinfo’: Permission denied
# find: ‘/proc/854/task/1301/ns’: Permission denied
# find: ‘/proc/854/task/1305/fd’: Permission denied
# find: ‘/proc/854/task/1305/fdinfo’: Permission denied
# find: ‘/proc/854/task/1305/ns’: Permission denied
# find: ‘/proc/854/task/1306/fd’: Permission denied
# find: ‘/proc/854/task/1306/fdinfo’: Permission denied
# find: ‘/proc/854/task/1306/ns’: Permission denied
# find: ‘/proc/854/task/1403/fd’: Permission denied
# find: ‘/proc/854/task/1403/fdinfo’: Permission denied
# find: ‘/proc/854/task/1403/ns’: Permission denied
# find: ‘/proc/854/task/12170/fd’: Permission denied
# find: ‘/proc/854/task/12170/fdinfo’: Permission denied
# find: ‘/proc/854/task/12170/ns’: Permission denied
# find: ‘/proc/854/task/13169/fd’: Permission denied
# find: ‘/proc/854/task/13169/fdinfo’: Permission denied
# find: ‘/proc/854/task/13169/ns’: Permission denied
# find: ‘/proc/854/task/14084/fd’: Permission denied
# find: ‘/proc/854/task/14084/fdinfo’: Permission denied
# find: ‘/proc/854/task/14084/ns’: Permission denied
# find: ‘/proc/854/task/17746/fd’: Permission denied
# find: ‘/proc/854/task/17746/fdinfo’: Permission denied
# find: ‘/proc/854/task/17746/ns’: Permission denied
# find: ‘/proc/854/task/15958/fd’: Permission denied
# find: ‘/proc/854/task/15958/fdinfo’: Permission denied
# find: ‘/proc/854/task/15958/ns’: Permission denied
# find: ‘/proc/854/fd’: Permission denied
# find: ‘/proc/854/map_files’: Permission denied
# find: ‘/proc/854/fdinfo’: Permission denied
# find: ‘/proc/854/ns’: Permission denied
# ...
# find: ‘/proc/19553/task/19553/fdinfo’: Permission denied
# find: ‘/proc/19553/task/19553/ns’: Permission denied
# find: ‘/proc/19553/fd’: Permission denied
# find: ‘/proc/19553/map_files’: Permission denied
# find: ‘/proc/19553/fdinfo’: Permission denied
# find: ‘/proc/19553/ns’: Permission denied
# find: ‘/proc/19577/task/19577/fd’: Permission denied
# find: ‘/proc/19577/task/19577/fdinfo’: Permission denied
# find: ‘/proc/19577/task/19577/ns’: Permission denied
# find: ‘/proc/19577/fd’: Permission denied
# find: ‘/proc/19577/map_files’: Permission denied
# find: ‘/proc/19577/fdinfo’: Permission denied
# find: ‘/proc/19577/ns’: Permission denied
# find: ‘/proc/19578/task/19578/fd’: Permission denied
# find: ‘/proc/19578/task/19578/fdinfo’: Permission denied
# find: ‘/proc/19578/task/19578/ns’: Permission denied
# find: ‘/proc/19578/fd’: Permission denied
# find: ‘/proc/19578/map_files’: Permission denied
# find: ‘/proc/19578/fdinfo’: Permission denied
# find: ‘/proc/19578/ns’: Permission denied
# find: ‘/proc/19581/task/19581/fd’: Permission denied
# find: ‘/proc/19581/task/19581/fdinfo’: Permission denied
# find: ‘/proc/19581/task/19581/ns’: Permission denied
# find: ‘/proc/19581/fd’: Permission denied
# find: ‘/proc/19581/map_files’: Permission denied
# find: ‘/proc/19581/fdinfo’: Permission denied
# find: ‘/proc/19581/ns’: Permission denied
# find: ‘/proc/19589/task/19589/fd’: Permission denied
# find: ‘/proc/19589/task/19589/fdinfo’: Permission denied
# find: ‘/proc/19589/task/19589/ns’: Permission denied
# find: ‘/proc/19589/fd’: Permission denied
# find: ‘/proc/19589/map_files’: Permission denied
# find: ‘/proc/19589/fdinfo’: Permission denied
# find: ‘/proc/19589/ns’: Permission denied
# find: ‘/proc/19590/task/19590/fd’: Permission denied
# find: ‘/proc/19590/task/19590/fdinfo’: Permission denied
# find: ‘/proc/19590/task/19590/ns’: Permission denied
# find: ‘/proc/19590/fd’: Permission denied
# find: ‘/proc/19590/map_files’: Permission denied
# find: ‘/proc/19590/fdinfo’: Permission denied
# find: ‘/proc/19590/ns’: Permission denied
# find: ‘/proc/19591/task/19591/fd’: Permission denied
# find: ‘/proc/19591/task/19591/fdinfo’: Permission denied
# find: ‘/proc/19591/task/19591/ns’: Permission denied
# find: ‘/proc/19591/fd’: Permission denied
# find: ‘/proc/19591/map_files’: Permission denied
# find: ‘/proc/19591/fdinfo’: Permission denied
# find: ‘/proc/19591/ns’: Permission denied
# find: ‘/proc/19592/task/19592/fd’: Permission denied
# find: ‘/proc/19592/task/19592/fdinfo’: Permission denied
# find: ‘/proc/19592/task/19592/ns’: Permission denied
# find: ‘/proc/19592/fd’: Permission denied
# find: ‘/proc/19592/map_files’: Permission denied
# find: ‘/proc/19592/fdinfo’: Permission denied
# find: ‘/proc/19592/ns’: Permission denied
# find: ‘/proc/19637/task/19637/fd’: Permission denied
# find: ‘/proc/19637/task/19637/fdinfo’: Permission denied
# find: ‘/proc/19637/task/19637/ns’: Permission denied
# find: ‘/proc/19637/fd’: Permission denied
# find: ‘/proc/19637/map_files’: Permission denied
# find: ‘/proc/19637/fdinfo’: Permission denied
# find: ‘/proc/19637/ns’: Permission denied
# find: ‘/proc/19649/task/19649/fd’: Permission denied
# find: ‘/proc/19649/task/19649/fdinfo’: Permission denied
# find: ‘/proc/19649/task/19649/ns’: Permission denied
# find: ‘/proc/19649/fd’: Permission denied
# find: ‘/proc/19649/map_files’: Permission denied
# find: ‘/proc/19649/fdinfo’: Permission denied
# find: ‘/proc/19649/ns’: Permission denied
# find: ‘/proc/19651/task/19651/fd’: Permission denied
# find: ‘/proc/19651/task/19651/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19651/ns’: Permission denied
# find: ‘/proc/19651/task/19658/fd’: Permission denied
# find: ‘/proc/19651/task/19658/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19658/ns’: Permission denied
# find: ‘/proc/19651/task/19659/fd’: Permission denied
# find: ‘/proc/19651/task/19659/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19659/ns’: Permission denied
# find: ‘/proc/19651/task/19660/fd’: Permission denied
# find: ‘/proc/19651/task/19660/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19660/ns’: Permission denied
# find: ‘/proc/19651/task/19662/fd’: Permission denied
# find: ‘/proc/19651/task/19662/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19662/ns’: Permission denied
# find: ‘/proc/19651/task/19663/fd’: Permission denied
# find: ‘/proc/19651/task/19663/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19663/ns’: Permission denied
# find: ‘/proc/19651/task/19675/fd’: Permission denied
# find: ‘/proc/19651/task/19675/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19675/ns’: Permission denied
# find: ‘/proc/19651/task/19677/fd’: Permission denied
# find: ‘/proc/19651/task/19677/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19677/ns’: Permission denied
# find: ‘/proc/19651/task/19679/fd’: Permission denied
# find: ‘/proc/19651/task/19679/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19679/ns’: Permission denied
# find: ‘/proc/19651/task/19680/fd’: Permission denied
# find: ‘/proc/19651/task/19680/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19680/ns’: Permission denied
# find: ‘/proc/19651/task/19681/fd’: Permission denied
# find: ‘/proc/19651/task/19681/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19681/ns’: Permission denied
# find: ‘/proc/19651/task/19682/fd’: Permission denied
# find: ‘/proc/19651/task/19682/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19682/ns’: Permission denied
# find: ‘/proc/19651/task/19683/fd’: Permission denied
# find: ‘/proc/19651/task/19683/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19683/ns’: Permission denied
# find: ‘/proc/19651/task/19684/fd’: Permission denied
# find: ‘/proc/19651/task/19684/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19684/ns’: Permission denied
# find: ‘/proc/19651/task/19708/fd’: Permission denied
# find: ‘/proc/19651/task/19708/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19708/ns’: Permission denied
# find: ‘/proc/19651/task/19712/fd’: Permission denied
# find: ‘/proc/19651/task/19712/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19712/ns’: Permission denied
# find: ‘/proc/19651/task/19713/fd’: Permission denied
# find: ‘/proc/19651/task/19713/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19713/ns’: Permission denied
# find: ‘/proc/19651/task/19714/fd’: Permission denied
# find: ‘/proc/19651/task/19714/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19714/ns’: Permission denied
# find: ‘/proc/19651/task/19715/fd’: Permission denied
# find: ‘/proc/19651/task/19715/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19715/ns’: Permission denied
# find: ‘/proc/19651/task/19837/fd’: Permission denied
# find: ‘/proc/19651/task/19837/fdinfo’: Permission denied
# find: ‘/proc/19651/task/19837/ns’: Permission denied
# find: ‘/proc/19651/fd’: Permission denied
# find: ‘/proc/19651/map_files’: Permission denied
# find: ‘/proc/19651/fdinfo’: Permission denied
# find: ‘/proc/19651/ns’: Permission denied
# find: ‘/proc/19753/task/19753/fd’: Permission denied
# find: ‘/proc/19753/task/19753/fdinfo’: Permission denied
# find: ‘/proc/19753/task/19753/ns’: Permission denied
# find: ‘/proc/19753/fd’: Permission denied
# find: ‘/proc/19753/map_files’: Permission denied
# find: ‘/proc/19753/fdinfo’: Permission denied
# find: ‘/proc/19753/ns’: Permission denied
# find: ‘/proc/19757/task/19757/fd’: Permission denied
# find: ‘/proc/19757/task/19757/fdinfo’: Permission denied
# find: ‘/proc/19757/task/19757/ns’: Permission denied
# find: ‘/proc/19757/fd’: Permission denied
# find: ‘/proc/19757/map_files’: Permission denied
# find: ‘/proc/19757/fdinfo’: Permission denied
# find: ‘/proc/19757/ns’: Permission denied
# find: ‘/proc/19797/task/19797/fd’: Permission denied
# find: ‘/proc/19797/task/19797/fdinfo’: Permission denied
# find: ‘/proc/19797/task/19797/ns’: Permission denied
# find: ‘/proc/19797/fd’: Permission denied
# find: ‘/proc/19797/map_files’: Permission denied
# find: ‘/proc/19797/fdinfo’: Permission denied
# find: ‘/proc/19797/ns’: Permission denied
# find: ‘/proc/19798/task/19798/fd’: Permission denied
# find: ‘/proc/19798/task/19798/fdinfo’: Permission denied
# find: ‘/proc/19798/task/19798/ns’: Permission denied
# find: ‘/proc/19798/fd’: Permission denied
# find: ‘/proc/19798/map_files’: Permission denied
# find: ‘/proc/19798/fdinfo’: Permission denied
# find: ‘/proc/19798/ns’: Permission denied
# find: ‘/proc/19821/task/19821/fd’: Permission denied
# find: ‘/proc/19821/task/19821/fdinfo’: Permission denied
# find: ‘/proc/19821/task/19821/ns’: Permission denied
# find: ‘/proc/19821/fd’: Permission denied
# find: ‘/proc/19821/map_files’: Permission denied
# find: ‘/proc/19821/fdinfo’: Permission denied
# find: ‘/proc/19821/ns’: Permission denied
# find: ‘/proc/19822/task/19822/fd’: Permission denied
# find: ‘/proc/19822/task/19822/fdinfo’: Permission denied
# find: ‘/proc/19822/task/19822/ns’: Permission denied
# find: ‘/proc/19822/fd’: Permission denied
# find: ‘/proc/19822/map_files’: Permission denied
# find: ‘/proc/19822/fdinfo’: Permission denied
# find: ‘/proc/19822/ns’: Permission denied
# find: ‘/proc/19823/task/19823/fd’: Permission denied
# find: ‘/proc/19823/task/19823/fdinfo’: Permission denied
# find: ‘/proc/19823/task/19823/ns’: Permission denied
# find: ‘/proc/19823/fd’: Permission denied
# find: ‘/proc/19823/map_files’: Permission denied
# find: ‘/proc/19823/fdinfo’: Permission denied
# find: ‘/proc/19823/ns’: Permission denied
# find: ‘/proc/19824/task/19824/fd’: Permission denied
# find: ‘/proc/19824/task/19824/fdinfo’: Permission denied
# find: ‘/proc/19824/task/19824/ns’: Permission denied
# find: ‘/proc/19824/fd’: Permission denied
# find: ‘/proc/19824/map_files’: Permission denied
# find: ‘/proc/19824/fdinfo’: Permission denied
# find: ‘/proc/19824/ns’: Permission denied
# find: ‘/proc/19825/task/19825/fd’: Permission denied
# find: ‘/proc/19825/task/19825/fdinfo’: Permission denied
# find: ‘/proc/19825/task/19825/ns’: Permission denied
# find: ‘/proc/19825/fd’: Permission denied
# find: ‘/proc/19825/map_files’: Permission denied
# find: ‘/proc/19825/fdinfo’: Permission denied
# find: ‘/proc/19825/ns’: Permission denied
# find: ‘/proc/27356/task/27356/fd’: Permission denied
# find: ‘/proc/27356/task/27356/fdinfo’: Permission denied
# find: ‘/proc/27356/task/27356/ns’: Permission denied
# find: ‘/proc/27356/fd’: Permission denied
# find: ‘/proc/27356/map_files’: Permission denied
# find: ‘/proc/27356/fdinfo’: Permission denied
# find: ‘/proc/27356/ns’: Permission denied
# find: ‘/proc/27357/task/27357/fd’: Permission denied
# find: ‘/proc/27357/task/27357/fdinfo’: Permission denied
# find: ‘/proc/27357/task/27357/ns’: Permission denied
# find: ‘/proc/27357/task/27376/fd’: Permission denied
# find: ‘/proc/27357/task/27376/fdinfo’: Permission denied
# find: ‘/proc/27357/task/27376/ns’: Permission denied
# find: ‘/proc/27357/task/27377/fd’: Permission denied
# find: ‘/proc/27357/task/27377/fdinfo’: Permission denied
# find: ‘/proc/27357/task/27377/ns’: Permission denied
# find: ‘/proc/27357/fd’: Permission denied
# find: ‘/proc/27357/map_files’: Permission denied
# find: ‘/proc/27357/fdinfo’: Permission denied
# find: ‘/proc/27357/ns’: Permission denied
# find: ‘/home/ramon/.gvfs’: Permission denied
# /home/ramon/ve/covid/lib/python3.6/site-packages/mesa/visualization/templates/js/ChartModule.js
# /home/ramon/git/covid-simulation/covid19_sir/notebooks/ramon/lib/ChartModule.js
# find: ‘/home/ramon/.dbus’: Permission denied
# find: ‘/home/ramon/.cache/doc’: Permission denied
# find: ‘/home/ramon/.cache/dconf’: Permission denied
# find: ‘/sys/kernel/debug’: Permission denied
# find: ‘/sys/fs/pstore’: Permission denied
# find: ‘/root’: Permission denied
# find: ‘/lost+found’: Permission denied
# find: ‘/var/log/speech-dispatcher’: Permission denied
# find: ‘/var/log/gdm3’: Permission denied
# find: ‘/var/spool/cups’: Permission denied
# find: ‘/var/spool/cron/crontabs’: Permission denied
# find: ‘/var/spool/rsyslog’: Permission denied
# find: ‘/var/cache/apt/archives/partial’: Permission denied
# find: ‘/var/cache/cups’: Permission denied
# find: ‘/var/cache/ldconfig’: Permission denied
# find: ‘/var/lib/containerd’: Permission denied
# find: ‘/var/lib/apt/lists/partial’: Permission denied
# find: ‘/var/lib/polkit-1’: Permission denied
# find: ‘/var/lib/geoclue/.cache’: Permission denied
# find: ‘/var/lib/gdm3/.local’: Permission denied
# find: ‘/var/lib/gdm3/.config/pulse’: Permission denied
# find: ‘/var/lib/gdm3/.config/gnome-session’: Permission denied
# find: ‘/var/lib/gdm3/.config/ibus’: Permission denied
# find: ‘/var/lib/gdm3/.config/dconf’: Permission denied
# find: ‘/var/lib/gdm3/.gnupg’: Permission denied
# find: ‘/var/lib/gdm3/.cache/libgweather’: Permission denied
# find: ‘/var/lib/fwupd/gnupg’: Permission denied
# find: ‘/var/lib/private’: Permission denied
# find: ‘/var/lib/udisks2’: Permission denied
# find: ‘/var/lib/colord/.cache’: Permission denied
# find: ‘/var/lib/update-notifier/package-data-downloads/partial’: Permission denied
# find: ‘/var/lib/docker’: Permission denied
# find: ‘/var/lib/snapd/void’: Permission denied
# find: ‘/var/lib/snapd/cookie’: Permission denied
# find: ‘/var/lib/snapd/cache’: Permission denied
# find: ‘/var/tmp/systemd-private-205b404aa7a246b28a60986de6124ec5-colord.service-cqOk1X’: Permission denied
# find: ‘/var/tmp/systemd-private-205b404aa7a246b28a60986de6124ec5-systemd-timesyncd.service-ub1V4y’: Permission denied
# find: ‘/var/tmp/systemd-private-205b404aa7a246b28a60986de6124ec5-bolt.service-e5yGvN’: Permission denied
# find: ‘/var/tmp/systemd-private-205b404aa7a246b28a60986de6124ec5-systemd-resolved.service-YPpVdf’: Permission denied
# find: ‘/var/tmp/systemd-private-205b404aa7a246b28a60986de6124ec5-rtkit-daemon.service-wNpIJE’: Permission denied
# find: ‘/var/tmp/systemd-private-205b404aa7a246b28a60986de6124ec5-ModemManager.service-KhI9kW’: Permission denied
# find: ‘/opt/containerd’: Permission denied
# find: ‘/etc/ssl/private’: Permission denied
# find: ‘/etc/cups/ssl’: Permission denied
# find: ‘/etc/polkit-1/localauthority’: Permission denied
# find: ‘/snap/core/10577/etc/ssl/private’: Permission denied
# find: ‘/snap/core/10577/root’: Permission denied
# find: ‘/snap/core/10577/var/cache/ldconfig’: Permission denied
# find: ‘/snap/core/10577/var/lib/machines’: Permission denied
# find: ‘/snap/core/10577/var/lib/private’: Permission denied
# find: ‘/snap/core/10577/var/lib/snapd/void’: Permission denied
# find: ‘/snap/core/10577/var/lib/waagent’: Permission denied
# find: ‘/snap/core/10577/var/spool/cron/crontabs’: Permission denied
# find: ‘/snap/core/10577/var/spool/rsyslog’: Permission denied
# find: ‘/snap/core/10444/etc/ssl/private’: Permission denied
# find: ‘/snap/core/10444/root’: Permission denied
# find: ‘/snap/core/10444/var/cache/ldconfig’: Permission denied
# find: ‘/snap/core/10444/var/lib/machines’: Permission denied
# find: ‘/snap/core/10444/var/lib/private’: Permission denied
# find: ‘/snap/core/10444/var/lib/snapd/void’: Permission denied
# find: ‘/snap/core/10444/var/lib/waagent’: Permission denied
# find: ‘/snap/core/10444/var/spool/cron/crontabs’: Permission denied
# find: ‘/snap/core/10444/var/spool/rsyslog’: Permission denied
# find: ‘/snap/core18/1944/etc/ssl/private’: Permission denied
# find: ‘/snap/core18/1944/root’: Permission denied
# find: ‘/snap/core18/1944/var/cache/ldconfig’: Permission denied
# find: ‘/snap/core18/1944/var/lib/private’: Permission denied
# find: ‘/snap/core18/1932/etc/ssl/private’: Permission denied
# find: ‘/snap/core18/1932/root’: Permission denied
# find: ‘/snap/core18/1932/var/cache/ldconfig’: Permission denied
# find: ‘/snap/core18/1932/var/lib/private’: Permission denied
# find: ‘/tmp/systemd-private-205b404aa7a246b28a60986de6124ec5-bolt.service-vC3G7d’: Permission denied
# find: ‘/tmp/systemd-private-205b404aa7a246b28a60986de6124ec5-rtkit-daemon.service-bv5zKa’: Permission denied
# find: ‘/tmp/systemd-private-205b404aa7a246b28a60986de6124ec5-systemd-resolved.service-R9lq9T’: Permission denied
# find: ‘/tmp/systemd-private-205b404aa7a246b28a60986de6124ec5-systemd-timesyncd.service-tEkrbe’: Permission denied
# find: ‘/tmp/systemd-private-205b404aa7a246b28a60986de6124ec5-ModemManager.service-De6wMA’: Permission denied
# find: ‘/tmp/systemd-private-205b404aa7a246b28a60986de6124ec5-colord.service-d08uLn’: Permission denied
# find: ‘/tmp/snap.canonical-livepatch’: Permission denied

# %%
import copy
import numpy as np
from model.base import CovidModel, SimulationParameters, set_parameters, normal_ci, get_parameters
from utils import BasicStatistics, RemovePolicy, Propaganda, setup_grid_layout, setup_city_layout, AddPolicy, AddPolicyInfectedRate, confidence_interval#, multiple_runs
from model.utils import SocialPolicy
from model.human import Elder, Adult, K12Student, Toddler, Infant, Human
from mesa.visualization.modules import CanvasGrid, ChartModule, TextElement
from mesa.visualization.ModularVisualization import ModularServer

# %%
def compute_color_intensity(color, v, lower_bound, upper_bound):
    """
    Computes color intensity - alpha - value from lower_bound (minimum) to upper_bound(maximum), proportionally. Returns the modified HTML color (and intensity) string.
    
    :param color: HTML color string;
    :param v: current value;
    :param lower_bound: maximum intensity value;
    :param upper_bound: minimum intensity value;
    :return: HTML color string for the selected color with intensity (alpha) varying from 0 to 100% based on the value range. 
    """
    if v > upper_bound:
        print("Warning: alpha value greater than upper bound!!!")
        v = upper_bound
    elif v < lower_bound:
        print("Warning: alpha value smaller than lower bound!!!")
        v = lower_bound
    max_alpha = 255
    min_alpha = 0
    v = (((v - lower_bound) / (upper_bound - lower_bound)) * (max_alpha - min_alpha)) + min_alpha
    if v > 255: v = 255
    alpha = format(int(round(v)), '02x').upper()
    return color + alpha


def agent_portrayal(agent):
    """
    Agent portrayal method for MESA component. Defines how each agent on the grid will be displayed.
    
    :param agent: agent in the simulation grid;
    :return: an agent portrayal dictionary.
    """
    portrayal = {"Shape": "rect",
                 "Filled": "true"}
    if agent.name.startswith("Home"):
        humans = [h for h in agent.allocation if isinstance(h, Human)]
        num_humans = len(humans)
        num_infected = len([h for h in humans if h.is_infected()])
#         all_humans = [h for h in agent.covid_model.agents if isinstance(h, Human)]
#         humans = [h for h in all_humans if h.home_district and h.home_district.strid == agent.strid]
#         num_humans = len(humans)
#         num_infected = len([h for h in humans if h.is_infected()])
        num_hospitalized = len([h for h in humans if h.is_hospitalized()])
        if num_hospitalized > num_humans * get_parameters().params['hospitalization_capacity']:
            portrayal = {"Shape": "rect",
                        "Filled": "true",
                        "Color": "#FC9803FF",
                        "w": .7,
                        "h": .7,
                        "Layer": 1}
            return portrayal
        portrayal["w"] = .7
        portrayal["h"] = .7
        portrayal["Layer"] = 1
        if num_infected >= 1:
            portrayal["Color"] = compute_color_intensity('#FF0A0A', num_infected, 0, 7)
        else:
            portrayal["Color"] = "#0AFF0E55"
        return portrayal
    elif agent.name.startswith("F_"):
        real_agent_name = agent.name.split('_')[1]
        all_humans = [h for h in agent.covid_model.agents if isinstance(h, Human)]
        humans = [h for h in all_humans if h.home_district and h.home_district.name == real_agent_name]
        num_dead = len([h for h in humans if h.is_dead])
        if num_dead >= 1:
            portrayal = {"Shape": "circle",
                        "Filled": "true",
                        "Color": "#000000AA",
                        "r": num_dead/10,
                        "Layer": 2}
            return portrayal
        else:
            return None
    elif agent.name.startswith("School"):
        humans = [h for h in agent.allocation if isinstance(h, Human)]
        num_humans = len(humans)
        num_infected = len([h for h in humans if h.is_infected()])
#         all_humans = [h for h in agent.covid_model.agents if isinstance(h, Human)]
#         humans = [h for h in all_humans if h.school_district and h.school_district.strid == agent.strid]
#         num_humans = len(humans)
#         num_infected = len([h for h in humans if h.is_infected()])
#         print(agent.name + " Humans: " + str(num_humans) + " Infected: " + str(num_infected))
        portrayal["w"] = 1.
        portrayal["h"] = 1.
        portrayal["Layer"] = 0 
        print("SCHOOL infected proportion: " + str(np.round(num_infected / num_humans,2)))
        if (num_infected / num_humans) >= 0.02:
            portrayal["Color"] = "#FC7B0355"
        else:
            portrayal["Color"] = "#00FF9155"
        return portrayal
    return portrayal


class InfectedText(TextElement):
    """
    Displays a centralized, padded version of the input text (defined on the constructor) on MESA server.
    """
    
    def __init__(self, text):
        self.text = "<p style=\"text-align:center;padding-top:20px;\">" + text + "</p>"
        pass
    def render(self, model):
        return self.text

# %% [markdown]
# ## Scenarios
# The following cell contains parameters for 6 different scenarios following Ben's suggestions.

# %%
# Fixed Parameters
population_size = 1000
simulation_cycles = 60 # days
seed = 5

# Changing parameters
scenarios_dict = {
    # 1) No clumpiness, no lockdown (lots of spreading)
    'scenario_1': { 'parameters': SimulationParameters(
                                    mask_user_rate = 0.0,
                                    mask_efficacy = 0.0,
                                    imune_rate = 0.01,
                                    initial_infection_rate = 0.01,
                                    hospitalization_capacity = 0.05,
                                    latency_period_shape = 3,
                                    latency_period_scale = 1, 
                                    incubation_period_shape = 6,
                                    incubation_period_scale = 1, 
                                    mild_period_duration_shape = 14,
                                    mild_period_duration_scale = 1,
                                    hospitalization_period_duration_shape = 12,
                                    hospitalization_period_duration_scale = 1,
                                    symptomatic_isolation_rate = 0.0,
                                    asymptomatic_contagion_probability = 0.1,
                                    risk_tolerance_mean = 0.7,
                                    risk_tolerance_stdev = 0.2,
                                    herding_behavior_mean = 0.7,
                                    herding_behavior_stdev = 0.2,
                                    allowed_restaurant_capacity = 1.0, # valid values: {1.0, 0.50, 0.25}
                                    spreading_rate = normal_ci(2.41, 3.90, 20)
                                ),
                   'listeners': [],
                        'home_grid_height': 6,
                        'home_grid_width' : 6,
                        'school_height' : 2,
                        'school_width' : 2,
                        'work_height' : 3,
                        'work_width' : 3
                  },
    # 2) High clumpiness, short lockdown (not such terrible spreading)
    'scenario_2': { 'parameters': SimulationParameters(
                                    mask_user_rate = 0.0,
                                    mask_efficacy = 0.0,
                                    imune_rate = 0.01,
                                    initial_infection_rate = 0.01,
                                    hospitalization_capacity = 0.05,
                                    latency_period_shape = 3,
                                    latency_period_scale = 1, 
                                    incubation_period_shape = 6,
                                    incubation_period_scale = 1, 
                                    mild_period_duration_shape = 14,
                                    mild_period_duration_scale = 1,
                                    hospitalization_period_duration_shape = 12,
                                    hospitalization_period_duration_scale = 1,
                                    symptomatic_isolation_rate = 0.0,
                                    asymptomatic_contagion_probability = 0.1,
                                    risk_tolerance_mean = 0.7,
                                    risk_tolerance_stdev = 0.2,
                                    herding_behavior_mean = 0.7,
                                    herding_behavior_stdev = 0.2,
                                    allowed_restaurant_capacity = 1.0, # valid values: {1.0, 0.50, 0.25}
                                    spreading_rate = normal_ci(2.41, 3.90, 20)
                                ),
                   'listeners': [
                            ["AddPolicy", SocialPolicy.LOCKDOWN_ELEMENTARY_SCHOOL, 20],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_MIDDLE_SCHOOL, 20],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_HIGH_SCHOOL, 20],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_RETAIL, 20],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_FACTORY, 20],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_OFFICE, 20],
                        ],
                        'home_grid_height': 6,
                        'home_grid_width' : 6,
                        'school_height' : 2,
                        'school_width' : 1,
                        'work_height' : 1,
                        'work_width' : 2
                  },
    # 3) Low clumpiness, short lockdown (lots of spreading). 
    'scenario_3': { 'parameters': SimulationParameters(
                                    mask_user_rate = 0.0,
                                    mask_efficacy = 0.0,
                                    imune_rate = 0.01,
                                    initial_infection_rate = 0.01,
                                    hospitalization_capacity = 0.05,
                                    latency_period_shape = 3,
                                    latency_period_scale = 1, 
                                    incubation_period_shape = 6,
                                    incubation_period_scale = 1, 
                                    mild_period_duration_shape = 14,
                                    mild_period_duration_scale = 1,
                                    hospitalization_period_duration_shape = 12,
                                    hospitalization_period_duration_scale = 1,
                                    symptomatic_isolation_rate = 0.0,
                                    asymptomatic_contagion_probability = 0.1,
                                    risk_tolerance_mean = 0.7,
                                    risk_tolerance_stdev = 0.2,
                                    herding_behavior_mean = 0.7,
                                    herding_behavior_stdev = 0.2,
                                    allowed_restaurant_capacity = 1.0, # valid values: {1.0, 0.50, 0.25}
                                    spreading_rate = normal_ci(2.41, 3.90, 20)
                                ),
                   'listeners': [
                            ["AddPolicy", SocialPolicy.LOCKDOWN_ELEMENTARY_SCHOOL, 20],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_MIDDLE_SCHOOL, 20],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_HIGH_SCHOOL, 20],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_RETAIL, 20],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_FACTORY, 20],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_OFFICE, 20],
                        ],
                        'home_grid_height': 6,
                        'home_grid_width' : 6,
                        'school_height' : 2,
                        'school_width' : 2,
                        'work_height' : 3,
                        'work_width' : 3
                  },
    # 4) High clumpiness, long lockdown (also not such terrible spreading). 
    'scenario_4': { 'parameters': SimulationParameters(
                                    mask_user_rate = 0.0,
                                    mask_efficacy = 0.0,
                                    imune_rate = 0.01,
                                    initial_infection_rate = 0.01,
                                    hospitalization_capacity = 0.05,
                                    latency_period_shape = 3,
                                    latency_period_scale = 1, 
                                    incubation_period_shape = 6,
                                    incubation_period_scale = 1, 
                                    mild_period_duration_shape = 14,
                                    mild_period_duration_scale = 1,
                                    hospitalization_period_duration_shape = 12,
                                    hospitalization_period_duration_scale = 1,
                                    symptomatic_isolation_rate = 0.0,
                                    asymptomatic_contagion_probability = 0.1,
                                    risk_tolerance_mean = 0.7,
                                    risk_tolerance_stdev = 0.2,
                                    herding_behavior_mean = 0.7,
                                    herding_behavior_stdev = 0.2,
                                    allowed_restaurant_capacity = 1.0, # valid values: {1.0, 0.50, 0.25}
                                    spreading_rate = normal_ci(2.41, 3.90, 20)
                                ),
                   'listeners': [
                            ["AddPolicy", SocialPolicy.LOCKDOWN_ELEMENTARY_SCHOOL, 1],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_MIDDLE_SCHOOL, 1],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_HIGH_SCHOOL, 1],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_RETAIL, 1],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_FACTORY, 1],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_OFFICE, 1],
                        ],
                        'home_grid_height': 6,
                        'home_grid_width' : 6,
                        'school_height' : 2,
                        'school_width' : 1,
                        'work_height' : 1,
                        'work_width' : 2
                  },
    # 5) No clumpiness, severe lockdown (very little spreading).
    'scenario_5': { 'parameters': SimulationParameters(
                                    mask_user_rate = 0.0,
                                    mask_efficacy = 0.0,
                                    imune_rate = 0.01,
                                    initial_infection_rate = 0.01,
                                    hospitalization_capacity = 0.05,
                                    latency_period_shape = 3,
                                    latency_period_scale = 1, 
                                    incubation_period_shape = 6,
                                    incubation_period_scale = 1, 
                                    mild_period_duration_shape = 14,
                                    mild_period_duration_scale = 1,
                                    hospitalization_period_duration_shape = 12,
                                    hospitalization_period_duration_scale = 1,
                                    symptomatic_isolation_rate = 0.0,
                                    asymptomatic_contagion_probability = 0.1,
                                    risk_tolerance_mean = 0.7,
                                    risk_tolerance_stdev = 0.2,
                                    herding_behavior_mean = 0.7,
                                    herding_behavior_stdev = 0.2,
                                    allowed_restaurant_capacity = 1.0, # valid values: {1.0, 0.50, 0.25}
                                    spreading_rate = normal_ci(2.41, 3.90, 20)
                                ),
                   'listeners': [
                            ["Propaganda", 1],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_ALL, 1]
                        ],
                        'home_grid_height': 6,
                        'home_grid_width' : 6,
                        'school_height' : 2,
                        'school_width' : 2,
                        'work_height' : 3,
                        'work_width' : 3
                  },
    # 6) No clumpiness, long lockdown (very little spreading).
    'scenario_6': { 'parameters': SimulationParameters(
                                    mask_user_rate = 0.0,
                                    mask_efficacy = 0.0,
                                    imune_rate = 0.01,
                                    initial_infection_rate = 0.01,
                                    hospitalization_capacity = 0.05,
                                    latency_period_shape = 3,
                                    latency_period_scale = 1, 
                                    incubation_period_shape = 6,
                                    incubation_period_scale = 1, 
                                    mild_period_duration_shape = 14,
                                    mild_period_duration_scale = 1,
                                    hospitalization_period_duration_shape = 12,
                                    hospitalization_period_duration_scale = 1,
                                    symptomatic_isolation_rate = 0.0,
                                    asymptomatic_contagion_probability = 0.1,
                                    risk_tolerance_mean = 0.7,
                                    risk_tolerance_stdev = 0.2,
                                    herding_behavior_mean = 0.7,
                                    herding_behavior_stdev = 0.2,
                                    allowed_restaurant_capacity = 1.0, # valid values: {1.0, 0.50, 0.25}
                                    spreading_rate = normal_ci(2.41, 3.90, 20)
                                ),
                   'listeners': [
                            ["AddPolicy", SocialPolicy.LOCKDOWN_ELEMENTARY_SCHOOL, 1],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_MIDDLE_SCHOOL, 1],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_HIGH_SCHOOL, 1],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_RETAIL, 1],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_FACTORY, 1],
                            ["AddPolicy", SocialPolicy.LOCKDOWN_OFFICE, 1],
                        ],
                        'home_grid_height': 6,
                        'home_grid_width' : 6,
                        'school_height' : 6,
                        'school_width' : 6,
                        'work_height' : 6,
                        'work_width' : 6
                  },
    
}

# %% [markdown]
# To pick one of them, simply change the scenario variable below:

# %%
# Selecting scenario
scenario = 'scenario_1'
parameters = scenarios_dict[scenario]['parameters']
listeners = scenarios_dict[scenario]['listeners']
home_grid_height = scenarios_dict[scenario]['home_grid_height']
home_grid_width = scenarios_dict[scenario]['home_grid_width']
school_height = scenarios_dict[scenario]['school_height']
school_width = scenarios_dict[scenario]['school_width']
work_height = scenarios_dict[scenario]['work_height']
work_width = scenarios_dict[scenario]['work_width']

# %% [markdown]
# ## Running the server

# %%
# Setting parameters and adding listeners
set_parameters(parameters)
model = CovidModel()
l = []
ls= copy.deepcopy(listeners)
for listener in ls:
    print(listener)
    funct = listener.pop(0)
    listener[:0]=[model]
    l.append(globals()[funct](*listener))
for k in l:
    model.add_listener(k)

# Setting up grid layout
setup_grid_layout(model, population_size, home_grid_height, home_grid_width, work_height, work_width, school_height, school_width)
statistics = BasicStatistics(model)
model.add_listener(statistics)

# Running server
text1= InfectedText("COVID 19 Simulation: Grid Visualization")
grid = CanvasGrid(agent_portrayal, home_grid_width, home_grid_height, 600, 600)
text2= InfectedText("Agent State Evolution Chart")
chart = ChartModule([{"Label": "Infected",
                      "Color": "Red"},
                    {"Label": "Hospitalized",
                      "Color": "Orange"},
                    {"Label": "Dead",
                      "Color": "Black"}],
                    data_collector_name='datacollector',
                    canvas_width=300
                   )

server = ModularServer(model, CovidModel,
                       [text1, grid, text2, chart],
                       "Covid Model",
                       {"N":100, "width":10, "height":10})
server.port = 8521 # The default
server.launch()
# Out:
# Interface starting at http://127.0.0.1:8521
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-e63a7b590e44> in <module>
#      36                        {"N":100, "width":10, "height":10})
#      37 server.port = 8521 # The default
# ---> 38 server.launch()
#
# ~/ve/covid/lib/python3.6/site-packages/mesa/visualization/ModularVisualization.py in launch(self, port, open_browser)
#     336             webbrowser.open(url)
#     337         tornado.autoreload.start()
# --> 338         tornado.ioloop.IOLoop.current().start()
#
# ~/ve/covid/lib/python3.6/site-packages/tornado/platform/asyncio.py in start(self)
#     147             self._setup_logging()
#     148             asyncio.set_event_loop(self.asyncio_loop)
# --> 149             self.asyncio_loop.run_forever()
#     150         finally:
#     151             asyncio.set_event_loop(old_loop)
#
# /usr/lib/python3.6/asyncio/base_events.py in run_forever(self)
#     423         self._check_closed()
#     424         if self.is_running():
# --> 425             raise RuntimeError('This event loop is already running')
#     426         if events._get_running_loop() is not None:
#     427             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# Socket opened!
# {"type":"reset"}
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.02
# SCHOOL infected proportion: 0.02
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.02
# SCHOOL infected proportion: 0.02
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.03
# SCHOOL infected proportion: 0.03
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.03
# SCHOOL infected proportion: 0.03
# SCHOOL infected proportion: 0.03
# SCHOOL infected proportion: 0.03
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.04
# SCHOOL infected proportion: 0.04
# SCHOOL infected proportion: 0.03
# SCHOOL infected proportion: 0.03
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.0
# SCHOOL infected proportion: 0.04
# SCHOOL infected proportion: 0.04
